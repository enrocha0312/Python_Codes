# %% [markdown]
# # Desafio: Consumo de Dados para Previsão do Tempo das Cidades do Vale do Paraíba.
#
# ## Objetivo
#
# Avaliar conhecimentos nas linguagens Python e SQL e na engine de processamento Apache Spark.
#
# ## Descrição
#
# Neste desafio, você desenvolverá um notebook que será responsável por extrair dados de previsão do tempo das cidades do Vale do Paraíba, região onde se localiza a Dataside. Para consultar todas as cidades dessa região, utilizaremos a API do IBGE. No caso, basta realizar uma requisição HTTP com o método GET, utilizando a URL abaixo:
#
# ```
# https://servicodados.ibge.gov.br/api/v1/localidades/mesorregioes/3513/municipios
# ```
#
# Com esses dados, gerar um data frame e a partir dele uma temp view. Ex: "cities"
#
# Utilizando os nomes das cidades, deverão ser consultados os dados de previsão de tempo para cada cidade. Para realizar essa consulta, poderá ser utilizada qualquer uma das APIs informadas no link abaixo.
#
# [Public APIs - Wather](https://github.com/public-apis/public-apis#weather)
#
# Obs.: Para algumas, pode ser necessário cadastrar-se para acessar sua API Key. Mas nenhuma delas deve precisar cadastrar cartão de crédito ou adicionar qualquer valor monetário para utilizar. Caso alguma solicite, basta optar por outra.
#
# Com os dados consultados, gerar um data frame e partir dele outra temp view. Ex: "forecasts"
#
# Com as temp views geradas, utilizar Spark SQL para criar queries e gerar data frames das seguintes tabelas:
#
# - Tabela 1: dados de previsão do tempo para os próximos cinco dias, para cada data e cidade consultadas. As colunas dessa tabela serão:
#     - Cidade
#     - CodigoDaCidade
#     - Data
#     - Regiao
#     - Pais
#     - Latitude
#     - Longigute
#     - TemperaturaMaxima
#     - TemperaturaMinima
#     - TemperaturaMedia
#     - VaiChover
#     - ChanceDeChuva
#     - CondicaoDoTempo
#     - NascerDoSol
#     - PorDoSol
#     - VelocidadeMaximaDoVento
#
#     Obs.: Os valores da coluna "VaiChover" deverá ser "Sim" ou "Não". E a coluna "CodigoDaCidade" é o ID retornado junto com os nomes da cidades na API do IBGE.
#     Obs.: Dependendo da API utilizada, algumas colunas podem não existir e ficarão em branco. Você deve optar por uma API que traga o maior número de informações possível.
#
# - Tabela 2: quantidade de dias com chuva e sem chuva para os dias consultados, para cada data consultada. Colunas:
#     - Cidade
#     - QtdDiasVaiChover
#     - QtdDiasNaoVaiChover
#     - TotalDiasMapeados
#
# Essas tabelas deverão ser exportadas em formado CSV e entregue no final do desafio.
#
# ## To Do
#
# [ ] - Consultar municípios do Vale do Paraíba, gerar um data frame e criar uma temp view com esses dados.
# [ ] - Consultar dados do tempo para cada município, gerar um data frame e criar uma outra temp view.
# [ ] - Utilizar Spark SQL para gerar os data frames das Tabelas 1 e 2.
# [ ] - Exportar os data frames para CSV.
#
# ## Atenção
#
# - Existe um limite de requisições de 10000 requests por conta cadastrada na m3o.
# - Essa API pode retornar cidades de outras regiões que possuem nome semelhante a alguma cidade do Vale do Paraiba. Pode mantê-las ou filtrar para gerar as tabelas apenas com dados de Regiao = Sao Paulo. Fica a seu critério.
#
# ## Entregando o desafio
#
# Concluindo todos os passos informados em To Do, basta salvar o arquivo .ipynb do notebook e enviar para a Dataside juntamente com os CSVs das duas tabelas.

# %%
import findspark
findspark.init()

import requests 
import json
import unidecode
from pyspark.sql import SparkSession

spark = SparkSession.builder \
      .master("local[1]") \
      .appName("SparkByExamples.com") \
      .getOrCreate()

# %%
# Buscar cidades do Vale do Paraíba
# TODO

# Criar data frame com as cidades
# TODO

# Criar view com as cidades
# TODO

# %%
# Buscar previsão do tempo para as cidades
# TODO

# Criar data frame com as previsões
# TODO

# Criar view com as previsões
# TODO

# %%
# Criar DF da Tabela 1
# TODO

# %%
# Criar DF da Tabela 2
# TODO

# %%
# Exportar CSVs
# TODO

# %%
#BUSCAR CIDADES DO VALE DO PARAÍBA PAULISTA
#1.VISUALIZAR
def mostrar_dados():
    request = requests.get("https://servicodados.ibge.gov.br/api/v1/localidades/mesorregioes/3513/municipios")
    print(request.content)
mostrar_dados()
# Out:
# b'[{"id":"3502507","nome":"Aparecida","microrregiao":{"id":35051,"nome":"Guaratinguet\xc3\xa1","mesorregiao":{"id":3513,"nome":"Vale do Para\xc3\xadba Paulista","UF":{"id":35,"sigla":"SP","nome":"S\xc3\xa3o Paulo","regiao":{"id":3,"sigla":"SE","nome":"Sudeste"}}}},"regiao-imediata":{"id":350052,"nome":"Guaratinguet\xc3\xa1","regiao-intermediaria":{"id":3511,"nome":"S\xc3\xa3o Jos\xc3\xa9 dos Campos","UF":{"id":35,"sigla":"SP","nome":"S\xc3\xa3o Paulo","regiao":{"id":3,"sigla":"SE","nome":"Sudeste"}}}}},{"id":"3503158","nome":"Arape\xc3\xad","microrregiao":{"id":35052,"nome":"Bananal","mesorregiao":{"id":3513,"nome":"Vale do Para\xc3\xadba Paulista","UF":{"id":35,"sigla":"SP","nome":"S\xc3\xa3o Paulo","regiao":{"id":3,"sigla":"SE","nome":"Sudeste"}}}},"regiao-imediata":{"id":350053,"nome":"Cruzeiro","regiao-intermediaria":{"id":3511,"nome":"S\xc3\xa3o Jos\xc3\xa9 dos Campos","UF":{"id":35,"sigla":"SP","nome":"S\xc3\xa3o Paulo","regiao":{"id":3,"sigla":"SE","nome":"Sudeste"}}}}},{"id":"3503505","nome":"Areias","microrregiao":{"id":35052,"nome":"Bananal","mesorregiao":{"id":3513,"nome":"Vale do Para\xc3\xadba Paulista","UF":{"id":35,"sigla":"SP","nome":"S\xc3\xa3o Paulo","regiao":{"id":3,"sigla":"SE","nome":"Sudeste"}}}},"regiao-imediata":{"id":350053,"nome":"Cruzeiro","regiao-intermediaria":{"id":3511,"nome":"S\xc3\xa3o Jos\xc3\xa9 dos Campos","UF":{"id":35,"sigla":"SP","nome":"S\xc3\xa3o Paulo","regiao":{"id":3,"sigla":"SE","nome":"Sudeste"}}}}},{"id":"3504909","nome":"Bananal","microrregiao":{"id":35052,"nome":"Bananal","mesorregiao":{"id":3513,"nome":"Vale do Para\xc3\xadba Paulista","UF":{"id":35,"sigla":"SP","nome":"S\xc3\xa3o Paulo","regiao":{"id":3,"sigla":"SE","nome":"Sudeste"}}}},"regiao-imediata":{"id":350053,"nome":"Cruzeiro","regiao-intermediaria":{"id":3511,"nome":"S\xc3\xa3o Jos\xc3\xa9 dos Campos","UF":{"id":35,"sigla":"SP","nome":"S\xc3\xa3o Paulo","regiao":{"id":3,"sigla":"SE","nome":"Sudeste"}}}}},{"id":"3508504","nome":"Ca\xc3\xa7apava","microrregiao":{"id":35050,"nome":"S\xc3\xa3o Jos\xc3\xa9 dos Campos","mesorregiao":{"id":3513,"nome":"Vale do Para\xc3\xadba Paulista","UF":{"id":35,"sigla":"SP","nome":"S\xc3\xa3o Paulo","regiao":{"id":3,"sigla":"SE","nome":"Sudeste"}}}},"regiao-imediata":{"id":350049,"nome":"S\xc3\xa3o Jos\xc3\xa9 dos Campos","regiao-intermediaria":{"id":3511,"nome":"S\xc3\xa3o Jos\xc3\xa9 dos Campos","UF":{"id":35,"sigla":"SP","nome":"S\xc3\xa3o Paulo","regiao":{"id":3,"sigla":"SE","nome":"Sudeste"}}}}},{"id":"3508603","nome":"Cachoeira Paulista","microrregiao":{"id":35051,"nome":"Guaratinguet\xc3\xa1","mesorregiao":{"id":3513,"nome":"Vale do Para\xc3\xadba Paulista","UF":{"id":35,"sigla":"SP","nome":"S\xc3\xa3o Paulo","regiao":{"id":3,"sigla":"SE","nome":"Sudeste"}}}},"regiao-imediata":{"id":350053,"nome":"Cruzeiro","regiao-intermediaria":{"id":3511,"nome":"S\xc3\xa3o Jos\xc3\xa9 dos Campos","UF":{"id":35,"sigla":"SP","nome":"S\xc3\xa3o Paulo","regiao":{"id":3,"sigla":"SE","nome":"Sudeste"}}}}},{"id":"3509700","nome":"Campos do Jord\xc3\xa3o","microrregiao":{"id":35049,"nome":"Campos do Jord\xc3\xa3o","mesorregiao":{"id":3513,"nome":"Vale do Para\xc3\xadba Paulista","UF":{"id":35,"sigla":"SP","nome":"S\xc3\xa3o Paulo","regiao":{"id":3,"sigla":"SE","nome":"Sudeste"}}}},"regiao-imediata":{"id":350050,"nome":"Taubat\xc3\xa9 - Pindamonhangaba","regiao-intermediaria":{"id":3511,"nome":"S\xc3\xa3o Jos\xc3\xa9 dos Campos","UF":{"id":35,"sigla":"SP","nome":"S\xc3\xa3o Paulo","regiao":{"id":3,"sigla":"SE","nome":"Sudeste"}}}}},{"id":"3509957","nome":"Canas","microrregiao":{"id":35051,"nome":"Guaratinguet\xc3\xa1","mesorregiao":{"id":3513,"nome":"Vale do Para\xc3\xadba Paulista","UF":{"id":35,"sigla":"SP","nome":"S\xc3\xa3o Paulo","regiao":{"id":3,"sigla":"SE","nome":"Sudeste"}}}},"regiao-imediata":{"id":350052,"nome":"Guaratinguet\xc3\xa1","regiao-intermediaria":{"id":3511,"nome":"S\xc3\xa3o Jos\xc3\xa9 dos Campos","UF":{"id":35,"sigla":"SP","nome":"S\xc3\xa3o Paulo","regiao":{"id":3,"sigla":"SE"," ...

# %%
#2.Passar dados para um json 
request = requests.get("https://servicodados.ibge.gov.br/api/v1/localidades/mesorregioes/3513/municipios")
dados = json.loads(request.content)

# %%
import findspark
findspark.init()
print(dados)
# Out:
# [{'id': '3502507', 'nome': 'Aparecida', 'microrregiao': {'id': 35051, 'nome': 'Guaratinguetá', 'mesorregiao': {'id': 3513, 'nome': 'Vale do Paraíba Paulista', 'UF': {'id': 35, 'sigla': 'SP', 'nome': 'São Paulo', 'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}, 'regiao-imediata': {'id': 350052, 'nome': 'Guaratinguetá', 'regiao-intermediaria': {'id': 3511, 'nome': 'São José dos Campos', 'UF': {'id': 35, 'sigla': 'SP', 'nome': 'São Paulo', 'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}, {'id': '3503158', 'nome': 'Arapeí', 'microrregiao': {'id': 35052, 'nome': 'Bananal', 'mesorregiao': {'id': 3513, 'nome': 'Vale do Paraíba Paulista', 'UF': {'id': 35, 'sigla': 'SP', 'nome': 'São Paulo', 'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}, 'regiao-imediata': {'id': 350053, 'nome': 'Cruzeiro', 'regiao-intermediaria': {'id': 3511, 'nome': 'São José dos Campos', 'UF': {'id': 35, 'sigla': 'SP', 'nome': 'São Paulo', 'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}, {'id': '3503505', 'nome': 'Areias', 'microrregiao': {'id': 35052, 'nome': 'Bananal', 'mesorregiao': {'id': 3513, 'nome': 'Vale do Paraíba Paulista', 'UF': {'id': 35, 'sigla': 'SP', 'nome': 'São Paulo', 'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}, 'regiao-imediata': {'id': 350053, 'nome': 'Cruzeiro', 'regiao-intermediaria': {'id': 3511, 'nome': 'São José dos Campos', 'UF': {'id': 35, 'sigla': 'SP', 'nome': 'São Paulo', 'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}, {'id': '3504909', 'nome': 'Bananal', 'microrregiao': {'id': 35052, 'nome': 'Bananal', 'mesorregiao': {'id': 3513, 'nome': 'Vale do Paraíba Paulista', 'UF': {'id': 35, 'sigla': 'SP', 'nome': 'São Paulo', 'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}, 'regiao-imediata': {'id': 350053, 'nome': 'Cruzeiro', 'regiao-intermediaria': {'id': 3511, 'nome': 'São José dos Campos', 'UF': {'id': 35, 'sigla': 'SP', 'nome': 'São Paulo', 'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}, {'id': '3508504', 'nome': 'Caçapava', 'microrregiao': {'id': 35050, 'nome': 'São José dos Campos', 'mesorregiao': {'id': 3513, 'nome': 'Vale do Paraíba Paulista', 'UF': {'id': 35, 'sigla': 'SP', 'nome': 'São Paulo', 'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}, 'regiao-imediata': {'id': 350049, 'nome': 'São José dos Campos', 'regiao-intermediaria': {'id': 3511, 'nome': 'São José dos Campos', 'UF': {'id': 35, 'sigla': 'SP', 'nome': 'São Paulo', 'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}, {'id': '3508603', 'nome': 'Cachoeira Paulista', 'microrregiao': {'id': 35051, 'nome': 'Guaratinguetá', 'mesorregiao': {'id': 3513, 'nome': 'Vale do Paraíba Paulista', 'UF': {'id': 35, 'sigla': 'SP', 'nome': 'São Paulo', 'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}, 'regiao-imediata': {'id': 350053, 'nome': 'Cruzeiro', 'regiao-intermediaria': {'id': 3511, 'nome': 'São José dos Campos', 'UF': {'id': 35, 'sigla': 'SP', 'nome': 'São Paulo', 'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}, {'id': '3509700', 'nome': 'Campos do Jordão', 'microrregiao': {'id': 35049, 'nome': 'Campos do Jordão', 'mesorregiao': {'id': 3513, 'nome': 'Vale do Paraíba Paulista', 'UF': {'id': 35, 'sigla': 'SP', 'nome': 'São Paulo', 'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}, 'regiao-imediata': {'id': 350050, 'nome': 'Taubaté - Pindamonhangaba', 'regiao-intermediaria': {'id': 3511, 'nome': 'São José dos Campos', 'UF': {'id': 35, 'sigla': 'SP', 'nome': 'São Paulo', 'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}, {'id': '3509957', 'nome': 'Canas', 'microrregiao': {'id': 35051, 'nome': 'Guaratinguetá', 'mesorregiao': {'id': 3513, 'nome': 'Vale do Paraíba Paulista', 'UF': {'id': 35, 'sigla': 'SP', 'nome': 'São Paulo', 'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}, 'regiao-imediata': {'id': 350052, 'nome': 'Guaratinguetá', 'regiao-intermediaria': {'id': 3511, 'nome': 'São José dos Campos', 'UF': {'id': 35, 'sigla': 'SP', 'nome': 'São Paulo', 'r ...

# %%
import pandas as pd

# %%
from pandas import json_normalize
dataframe_API = pd.json_normalize(dados)

# %%
#ver dados 
dataframe_API.head(3)
# Out:
#         id       nome  microrregiao.id microrregiao.nome  \
# 0  3502507  Aparecida            35051     Guaratinguetá
# 1  3503158     Arapeí            35052           Bananal
# 2  3503505     Areias            35052           Bananal
#
#    microrregiao.mesorregiao.id microrregiao.mesorregiao.nome  \
# 0                         3513      Vale do Paraíba Paulista
# 1                         3513      Vale do Paraíba Paulista
# 2                         3513      Vale do Paraíba Paulista
#
#    microrregiao.mesorregiao.UF.id microrregiao.mesorregiao.UF.sigla  \
# 0                              35                                SP
# 1                              35                                SP
# 2                              35                                SP
#
#   microrregiao.mesorregiao.UF.nome  microrregiao.mesorregiao.UF.regiao.id  \
# 0                        São Paulo                                      3
# 1                        São Paulo                                      3
# 2                        São Paulo                                      3
#
#    ... regiao-imediata.id regiao-imediata.nome  \
# 0  ...             350052        Guaratinguetá
# 1  ...             350053             Cruzeiro
# 2  ...             350053             Cruzeiro
#
#    regiao-imediata.regiao-intermediaria.id  \
# 0                                     3511
# 1                                     3511
# 2                                     3511
#
#   regiao-imediata.regiao-intermediaria.nome  \
# 0                       São José dos Campos
# 1                       São José dos Campos
# 2                       São José dos Campos
#
#    regiao-imediata.regiao-intermediaria.UF.id  \
# 0                                          35
# 1                                          35
# 2                                          35
#
#   regiao-imediata.regiao-intermediaria.UF.sigla  \
# 0                                            SP
# 1                                            SP
# 2                                            SP
#
#    regiao-imediata.regiao-intermediaria.UF.nome  \
# 0                                     São Paulo
# 1                                     São Paulo
# 2                                     São Paulo
#
#   regiao-imediata.regiao-intermediaria.UF.regiao.id  \
# 0                                                 3
# 1                                                 3
# 2                                                 3
#
#   regiao-imediata.regiao-intermediaria.UF.regiao.sigla  \
# 0                                                 SE
# 1                                                 SE
# 2                                                 SE
#
#    regiao-imediata.regiao-intermediaria.UF.regiao.nome
# 0                                            Sudeste
# 1                                            Sudeste
# 2                                            Sudeste
#
# [3 rows x 22 columns]

# %%
#3. Criar dataframe com spark
df1 = spark.createDataFrame(dataframe_API)

# %%
#ver cidades

cidades = dataframe_API["nome"]

# %%
cidadesLista = list(cidades)

# %%
cidadesLista
# Out:
# ['Aparecida',
#  'Arapeí',
#  'Areias',
#  'Bananal',
#  'Caçapava',
#  'Cachoeira Paulista',
#  'Campos do Jordão',
#  'Canas',
#  'Caraguatatuba',
#  'Cruzeiro',
#  'Cunha',
#  'Guaratinguetá',
#  'Igaratá',
#  'Ilhabela',
#  'Jacareí',
#  'Jambeiro',
#  'Lagoinha',
#  'Lavrinhas',
#  'Lorena',
#  'Monteiro Lobato',
#  'Natividade da Serra',
#  'Paraibuna',
#  'Pindamonhangaba',
#  'Piquete',
#  'Potim',
#  'Queluz',
#  'Redenção da Serra',
#  'Roseira',
#  'Santa Branca',
#  'Santo Antônio do Pinhal',
#  'São Bento do Sapucaí',
#  'São José do Barreiro',
#  'São José dos Campos',
#  'São Luiz do Paraitinga',
#  'São Sebastião',
#  'Silveiras',
#  'Taubaté',
#  'Tremembé',
#  'Ubatuba']

# %%
#A API Hg Brasil só permite utilizar requisição para até 10 cidades por dia. Farei para 7, mas o procedimento seguiria válido
#para n cidades

dfReduzido = dataframe_API.head(7)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 4>()
#       1 #A API Hg Brasil só permite utilizar requisição para até 10 cidades por dia. Farei para 7, mas o procedimento seguiria válido
#       2 #para n cidades
# ----> 4 dfReduzido = dataframe_API.head(7)
#
# NameError: name 'dataframe_API' is not defined

# %%
cidades7 = dfReduzido["nome"]

# %%
cidades7Lista = list(cidades7)

# %%
cidades7Lista
# Out:
# ['Aparecida',
#  'Arapeí',
#  'Areias',
#  'Bananal',
#  'Caçapava',
#  'Cachoeira Paulista',
#  'Campos do Jordão']

# %%
#é recomendado passar para URL COde para fazer as requisições (recomendação da documentação da própria API)

import urllib.parse

# %%
#passando para URL
cidadesURLCode = []
for cidade in cidades7Lista:
    cidadesURLCode.append(urllib.parse.quote(cidade))

cidadesURLCode
# Out:
# ['Aparecida',
#  'Arape%C3%AD',
#  'Areias',
#  'Bananal',
#  'Ca%C3%A7apava',
#  'Cachoeira%20Paulista',
#  'Campos%20do%20Jord%C3%A3o']

# %%
###funcao que cria todas as requisicoes de cidades 

def criaVetorRequisicoes (lista):
    listaRequisicao = []
    for cidade in lista:
        stringBase = "https://api.hgbrasil.com/weather?key=ee131789&city_name="
        stringRequisicao = stringBase + cidade
        requisicao = requests.get(stringRequisicao)
        listaRequisicao.append(json.loads(requisicao.content))
    return listaRequisicao

# %%
###Dados dataframe requisicoes de previsao do tempo
requisicoes_cidades = criaVetorRequisicoes(cidadesURLCode)

# %%
df_forecast = pd.json_normalize(requisicoes_cidades)

# %%
df_forecast.head(7)
# Out:
#           by  valid_key  execution_time  from_cache  results.temp  \
# 0  city_name       True            0.00        True            34
# 1  city_name       True            0.52       False            23
# 2  city_name       True            0.00        True            23
# 3    default       True            0.35       False            23
# 4      woeid       True            0.35       False            23
# 5      woeid       True            0.76       False            25
# 6  city_name       True            0.00        True            16
#
#   results.date results.time results.condition_code   results.description  \
# 0   05/05/2022        15:49                     28         Tempo nublado
# 1   05/05/2022        15:49                     27           Tempo limpo
# 2   05/05/2022        15:34                     27           Tempo limpo
# 3   05/05/2022        15:49                     27           Tempo limpo
# 4   05/05/2022        15:49                     29  Parcialmente nublado
# 5   05/05/2022        15:49                     27           Tempo limpo
# 6   05/05/2022        15:27                     27           Tempo limpo
#
#   results.currently results.cid            results.city results.img_id  \
# 0               dia                       Aparecida, PB             28
# 1               dia                          Arapeí, SP             27
# 2               dia                          Areias, SP             27
# 3               dia                         Bananal, SP             27
# 4               dia                        Caçapava, SP             29
# 5               dia              Cachoeira Paulista, SP             27
# 6               dia                Campos do Jordão, SP             27
#
#    results.humidity results.wind_speedy results.sunrise results.sunset  \
# 0                34           5.44 km/h        05:33 am       05:24 pm
# 1                63           1.24 km/h        06:18 am       05:29 pm
# 2                51           2.91 km/h        06:18 am       05:30 pm
# 3                63           1.24 km/h        06:18 am       05:29 pm
# 4                66           3.11 km/h        06:24 am       05:34 pm
# 5                56           2.31 km/h        06:20 am       05:32 pm
# 6                54           0.76 km/h        06:23 am       05:34 pm
#
#   results.condition_slug   results.city_name  \
# 0            cloudly_day           Aparecida
# 1              clear_day              Arapeí
# 2              clear_day              Areias
# 3              clear_day             Bananal
# 4            cloudly_day            Caçapava
# 5              clear_day  Cachoeira Paulista
# 6              clear_day    Campos do Jordão
#
#                                     results.forecast
# 0  [{'date': '05/05', 'weekday': 'Qui', 'max': 34...
# 1  [{'date': '05/05', 'weekday': 'Qui', 'max': 25...
# 2  [{'date': '05/05', 'weekday': 'Qui', 'max': 26...
# 3  [{'date': '05/05', 'weekday': 'Qui', 'max': 25...
# 4  [{'date': '05/05', 'weekday': 'Qui', 'max': 22...
# 5  [{'date': '05/05', 'weekday': 'Qui', 'max': 25...
# 6  [{'date': '05/05', 'weekday': 'Qui', 'max': 17...

# %%
#CRIAÇÃO DF TABELA 1

df_forecast["results.forecast"]
# Out:
# 0    [{'date': '05/05', 'weekday': 'Qui', 'max': 34...
# 1    [{'date': '05/05', 'weekday': 'Qui', 'max': 25...
# 2    [{'date': '05/05', 'weekday': 'Qui', 'max': 26...
# 3    [{'date': '05/05', 'weekday': 'Qui', 'max': 25...
# 4    [{'date': '05/05', 'weekday': 'Qui', 'max': 22...
# 5    [{'date': '05/05', 'weekday': 'Qui', 'max': 25...
# 6    [{'date': '05/05', 'weekday': 'Qui', 'max': 17...
# Name: results.forecast, dtype: object

# %%
# O FOrecasts contem a previsão para os próximos dias

df_proximosDias = df_forecast["results.forecast"]

# %%
df_proximosDias.head(7)
# Out:
# 0    [{'date': '05/05', 'weekday': 'Qui', 'max': 34...
# 1    [{'date': '05/05', 'weekday': 'Qui', 'max': 25...
# 2    [{'date': '05/05', 'weekday': 'Qui', 'max': 26...
# 3    [{'date': '05/05', 'weekday': 'Qui', 'max': 25...
# 4    [{'date': '05/05', 'weekday': 'Qui', 'max': 22...
# 5    [{'date': '05/05', 'weekday': 'Qui', 'max': 25...
# 6    [{'date': '05/05', 'weekday': 'Qui', 'max': 17...
# Name: results.forecast, dtype: object

# %%
type(df_proximosDias)
# Out:
# pandas.core.series.Series

# %%
listaProximosDias = list(df_proximosDias)

# %%
listaProximosDias
# Out:
# [[{'date': '05/05',
#    'weekday': 'Qui',
#    'max': 34,
#    'min': 20,
#    'description': 'Tempo nublado',
#    'condition': 'cloudly_day'},
#   {'date': '06/05',
#    'weekday': 'Sex',
#    'max': 34,
#    'min': 21,
#    'description': 'Tempo nublado',
#    'condition': 'cloudly_day'},
#   {'date': '07/05',
#    'weekday': 'Sáb',
#    'max': 32,
#    'min': 21,
#    'description': 'Chuvas esparsas',
#    'condition': 'rain'},
#   {'date': '08/05',
#    'weekday': 'Dom',
#    'max': 33,
#    'min': 22,
#    'description': 'Chuvas esparsas',
#    'condition': 'rain'},
#   {'date': '09/05',
#    'weekday': 'Seg',
#    'max': 33,
#    'min': 21,
#    'description': 'Chuvas esparsas',
#    'condition': 'rain'},
#   {'date': '10/05',
#    'weekday': 'Ter',
#    'max': 34,
#    'min': 21,
#    'description': 'Chuvas esparsas',
#    'condition': 'rain'},
#   {'date': '11/05',
#    'weekday': 'Qua',
#    'max': 34,
#    'min': 23,
#    'description': 'Chuvas esparsas',
#    'condition': 'rain'},
#   {'date': '12/05',
#    'weekday': 'Qui',
#    'max': 33,
#    'min': 23,
#    'description': 'Chuvas esparsas',
#    'condition': 'rain'},
#   {'date': '13/05',
#    'weekday': 'Sex',
#    'max': 34,
#    'min': 22,
#    'description': 'Chuvas esparsas',
#    'condition': 'rain'},
#   {'date': '14/05',
#    'weekday': 'Sáb',
#    'max': 33,
#    'min': 22,
#    'description': 'Chuvas esparsas',
#    'condition': 'rain'}],
#  [{'date': '05/05',
#    'weekday': 'Qui',
#    'max': 25,
#    'min': 15,
#    'description': 'Tempo limpo',
#    'condition': 'clear_day'},
#   {'date': '06/05',
#    'weekday': 'Sex',
#    'max': 23,
#    'min': 13,
#    'description': 'Chuvas esparsas',
#    'condition': 'rain'},
#   {'date': '07/05',
#    'weekday': 'Sáb',
#    'max': 21,
#    'min': 15,
#    'description': 'Chuvas esparsas',
#    'condition': 'rain'},
#   {'date': '08/05',
#    'weekday': 'Dom',
#    'max': 21,
#    'min': 15,
#    'description': 'Chuvas esparsas',
#    'condition': 'rain'},
#   {'date': '09/05',
#    'weekday': 'Seg',
#    'max': 23,
#    'min': 15,
#    'description': 'Tempo limpo',
#    'condition': 'clear_day'},
#   {'date': '10/05',
#    'weekday': 'Ter',
#    'max': 23,
#    'min': 13,
#    'description': 'Tempo limpo',
#    'condition': 'clear_day'},
#   {'date': '11/05',
#    'weekday': 'Qua',
#    'max': 19,
#    'min': 16,
#    'description': 'Chuva',
#    'condition': 'rain'},
#   {'date': '12/05',
#    'weekday': 'Qui',
#    'max': 23,
#    'min': 16,
#    'description': 'Chuvas esparsas',
#    'condition': 'rain'},
#   {'date': '13/05',
#    'weekday': 'Sex',
#    'max': 23,
#    'min': 14,
#    'description': 'Chuvas esparsas',
#    'condition': 'rain'},
#   {'date': '14/05',
#    'weekday': 'Sáb',
#    'max': 22,
#    'min': 16,
#    'description': 'Chuvas esparsas',
#    'condition': 'rain'}],
#  [{'date': '05/05',
#    'weekday': 'Qui',
#    'max': 26,
#    'min': 14,
#    'description': 'Tempo limpo',
#    'condition': 'clear_day'},
#   {'date': '06/05',
#    'weekday': 'Sex',
#    'max': 24,
#    'min': 13,
#    'description': 'Chuvas esparsas',
#    'condition': 'rain'},
#   {'date': '07/05',
#    'weekday': 'Sáb',
#    'max': 23,
#    'min': 17,
#    'description': 'Chuvas esparsas',
#    'condition': 'rain'},
#   {'date': '08/05',
#    'weekday': 'Dom',
#    'max': 22,
#    'min': 17,
#    'description': 'Chuvas esparsas',
#    'condition': 'rain'},
#   {'date': '09/05',
#    'weekday': 'Seg',
#    'max': 24,
#    'min': 16,
#    'description': 'Tempo limpo',
#    'condition': 'clear_day'},
#   {'date': '10/05',
#    'weekday': 'Ter',
#    'max': 24,
#    'min': 13,
#    'description': 'Parcialmente nublado',
#    'condition': 'cloudly_day'},
#   {'date': '11/05',
#    'weekday': 'Qua',
#    'max': 19,
#    'min': 17,
#    'description': 'Chuva',
#    'condition': 'rain'},
#   {'date': '12/05',
#    'weekday': 'Qui',
#    'max': 23,
#    'min': 16,
#    'description': 'Chuvas esparsas',
#    'condition': 'rain'},
#   {'date': '13/05',
#    'weekday': 'Sex',
#    'max': 23,
#    'min': 14,
#    'description': 'Chuvas esparsas',
#    'condition': 'rain'},
#   {'date': '14/05',
#    'weekday': 'Sáb',
#    'max': 23,
#    'min': 16,
#    'description': 'Parcialmente nublado',
#    'condition': 'cloud'}],
#  [{'date': '05/05',
#    'weekday': 'Qui',
#    'max': 25,
#    'min': 15,
#    'description': 'Tempo limpo',
#    'condition': 'clear_day'},
#   {'date': '06/05',
#    'weekday': 'Sex',
#    'max': 23,
#    'min': 13,
#    'description': 'Chuvas esparsas',
#    'condition': 'rain'},
#   {'date': '07/05',
#    'weekday': 'Sáb',
#    'max': 21,
#    'min': 15,
#    'description': 'Chuvas esparsas',
#    'condition': 'rain'},
#   {'date': '08/05',
#    'weekday': 'Dom',
#    'max': 21,
#    'min': 15,
#    'description': 'Chuvas esparsas',
#    'condition': 'rain'},
#   {'date': '09/05',
#    'weekday': 'Seg',
#    'max': 23,
#    'min': 15,
#    'description': 'Tempo limpo',
#    'condition': 'clear_day'},
#   {'date': '10/05',
#    'weekday': 'Ter',
#    'max': 23,
#    'min': 13,
#    'description': 'Tempo limpo',
#    'condition': 'clear_day'},
#   {'date': '11/05',
#    'weekday': 'Qua',
#    'max': 19,
#    'min': 16,
#    'description': 'Chuva',
#    'condition': 'rain'},
#   {'date': '12/05',
#    'weekday': 'Qui',
#    'max': 23,
#    'min': 16,
#    'description': 'Chuvas esparsas',
#    'condition': 'rain'},
#   {'date': '13/05',
#    'weekday': 'Sex',
#    'max': 23,
#    'min': 14,
#    'description': 'Chuvas esparsas',
#    'condition': 'rain'},
#   {'date': '14/05',
#    'weekday': 'Sáb',
#    'max': 22,
#    'min': 16,
#    'description': 'Chuvas esparsas',
#    'condition': 'rain'}],
#  [{'date': '05/05',
#    'weekday': 'Qui',
#    'max': 22,
#    'min': 10,
#    'description': 'Tempo limpo',
#    'condition': 'clear_day'},
#   {'date': '06/05',
#    'weekday': 'Sex',
#    'max': 24,
#    'min': 14,
#    'description': 'Parcialmente nublado',
#    'condition': 'cloud'},
#   {'date': '07/05',
#    'weekday': 'Sáb',
#    'max': 23,
#    'min': 14,
#    'description': 'Tempo nublado',
#    'condition': 'cloudly_day'},
#   {'date': '08/05',
#    'weekday': 'Dom',
#    'max': 23,
#    'min': 15,
#    'description': 'Tempo nublado',
#    'condition': 'cloudly_day'},
#   {'date': '09/05',
#    'weekday': 'Seg',
#    'max': 24,
#    'min': 14,
#    'description': 'Tempo nublado',
#    'condition': 'cloudly_day'},
#   {'date': '10/05',
#    'weekday': 'Ter',
#    'max': 25,
#    'min': 14,
#    'description': 'Parcialmente nublado',
#    'condition': 'cloud'},
#   {'date': '11/05',
#    'weekday': 'Qua',
#    'max': 18,
#    'min': 15,
#    'description': 'Chuva',
#    'condition': 'rain'},
#   {'date': '12/05',
#    'weekday': 'Qui',
#    'max': 22,
#    'min': 15,
#    'description': 'Chuvas esparsas',
#    'condition': 'rain'},
#   {'date': '13/05',
#    'weekday': 'Sex',
#    'max': 23,
#    'min': 16,
#    'description': 'Chuvas esparsas',
#    'condition': 'rain'},
#   {'date': '14/05',
#    'weekday': 'Sáb',
#    'max': 25,
#    'min': 16,
#    'description': 'Chuvas esparsas',
#    'condition': 'rain'}],
#  [{'date': '05/05',
#    'weekday': 'Qui',
#    'max': 25,
#    'min': 12,
#    'description': 'Tempo limpo',
#    'condition': 'clear_day'},
#   {'date': '06/05',
#    'weekday': 'Sex',
#    'max': 25,
#    'min': 13,
#    'description': 'Parcialmente nublado',
#    'condition': 'cloudly_day'},
#   {'date': '07/05',
#    'weekday': 'Sáb',
#    'max': 24,
#    'min': 14,
#    'description': 'Tempo nublado',
#    'condition': 'cloudly_day'},
#   {'date': '08/05',
#    'weekday': 'Dom',
#    'max': 24,
#    'min': 15,
#    'description': 'Parcialmente nublado',
#    'condition': 'cloud'},
#   {'date': '09/05',
#    'weekday': 'Seg',
#    'max': 24,
#    'min': 15,
#    'description': 'Parcialmente nublado',
#    'condition': 'cloud'},
#   {'date': '10/05',
#    'weekday': 'Ter',
#    'max': 26,
#    'min': 14,
#    'description': 'Tempo limpo',
#    'condition': 'clear_day'},
#   {'date': '11/05',
#    'weekday': 'Qua',
#    'max': 25,
#    'min': 14,
#    'description': 'Chuvas esparsas',
#    'condition': 'rain'},
#   {'date': '12/05',
#    'weekday': 'Qui',
#    'max': 24,
#    'min': 14,
#    'description': 'Chuvas esparsas',
#    'condition': 'rain'},
#   {'date': '13/05',
#    'weekday': 'Sex',
#    'max': 23,
#    'min': 17,
#    'description': 'Chuvas esparsas',
#    'condition': 'rain'},
#   {'date': '14/05',
#    'weekday': 'Sáb',
#    'max': 24,
#    'min': 16,
#    'description': 'Chuvas esparsas',
#    'condition': 'rain'}],
#  [{'date': '05/05',
#    'weekday': 'Qui',
#    'max': 17,
#    'min': 5,
#    'description': 'Tempo limpo',
#    'condition': 'clear_day'},
#   {'date': '06/05',
#    'weekday': 'Sex',
#    'max': 18,
#    'min': 7,
#    'description': 'Tempo limpo',
#    'condition': 'clear_day'},
#   {'date': '07/05',
#    'weekday': 'Sáb',
#    'max': 17,
#    'min': 9,
#    'description': 'Chuvas esparsas',
#    'condition': 'rain'},
#   {'date': '08/05',
#    'weekday': 'Dom',
#    'max': 17,
#    'min': 10,
#    'description': 'Chuvas esparsas',
#    'condition': 'rain'},
#   {'date': '09/05',
#    'weekday': 'Seg',
#    'max': 18,
#    'min': 10,
#    'description': 'Chuvas esparsas',
#    'condition': 'rain'},
#   {'date': '10/05',
#    'weekday': 'Ter',
#    'max': 19,
#    'min': 8,
#    'description': 'Chuva',
#    'condition': 'rain'},
#   {'date': '11/05',
#    'weekday': 'Qua',
#    'max': 13,
#    'min': 10,
#    'description': 'Chuva',
#    'condition': 'rain'},
#   {'date': '12/05',
#    'weekday': 'Qui',
#    'max': 14,
#    'min': 8,
#    'description': 'Tempo nublado',
#    'condition': 'cloudly_day'},
#   {'date': '13/05',
#    'weekday': 'Sex',
#    'max': 17,
#    'min': 7,
#    'description': 'Parcialmente nublado',
#    'condition': 'cloud'},
#   {'date': '14/05',
#    'weekday': 'Sáb',
#    'max': 18,
#    'min': 8,
#    'description': 'Chuvas esparsas',
#    'condition': 'rain'}]]

# %%
listaProximosDias[0][0:5]
# Out:
# [{'date': '05/05',
#   'weekday': 'Qui',
#   'max': 34,
#   'min': 20,
#   'description': 'Tempo nublado',
#   'condition': 'cloudly_day'},
#  {'date': '06/05',
#   'weekday': 'Sex',
#   'max': 34,
#   'min': 21,
#   'description': 'Tempo nublado',
#   'condition': 'cloudly_day'},
#  {'date': '07/05',
#   'weekday': 'Sáb',
#   'max': 32,
#   'min': 21,
#   'description': 'Chuvas esparsas',
#   'condition': 'rain'},
#  {'date': '08/05',
#   'weekday': 'Dom',
#   'max': 33,
#   'min': 22,
#   'description': 'Chuvas esparsas',
#   'condition': 'rain'},
#  {'date': '09/05',
#   'weekday': 'Seg',
#   'max': 33,
#   'min': 21,
#   'description': 'Chuvas esparsas',
#   'condition': 'rain'}]

# %%
#transformar em lista de dicts para trabalhar com dataframes
listaDicts1 = listaProximosDias[0][0:5]

# %%
listaDicts1
# Out:
# [{'date': '05/05',
#   'weekday': 'Qui',
#   'max': 34,
#   'min': 20,
#   'description': 'Tempo nublado',
#   'condition': 'cloudly_day'},
#  {'date': '06/05',
#   'weekday': 'Sex',
#   'max': 34,
#   'min': 21,
#   'description': 'Tempo nublado',
#   'condition': 'cloudly_day'},
#  {'date': '07/05',
#   'weekday': 'Sáb',
#   'max': 32,
#   'min': 21,
#   'description': 'Chuvas esparsas',
#   'condition': 'rain'},
#  {'date': '08/05',
#   'weekday': 'Dom',
#   'max': 33,
#   'min': 22,
#   'description': 'Chuvas esparsas',
#   'condition': 'rain'},
#  {'date': '09/05',
#   'weekday': 'Seg',
#   'max': 33,
#   'min': 21,
#   'description': 'Chuvas esparsas',
#   'condition': 'rain'}]

# %%
listaDicts2 = listaProximosDias[1][0:5] ##optei por nao automatizar essa parte por ser prático

# %%
listaDicts3 = listaProximosDias[2][0:5]
listaDicts4 = listaProximosDias[3][0:5]
listaDicts5 = listaProximosDias[4][0:5]
listaDicts6 = listaProximosDias[5][0:5]
listaDicts7 = listaProximosDias[6][0:5]

# %%
dfA = pd.DataFrame(listaDicts1)
dfB = pd.DataFrame(listaDicts2)
dfC = pd.DataFrame(listaDicts3)
dfD = pd.DataFrame(listaDicts4)
dfE = pd.DataFrame(listaDicts5)
dfF = pd.DataFrame(listaDicts6)
dfG = pd.DataFrame(listaDicts7)

# %%
dfA.head()
# Out:
#     date weekday  max  min      description    condition
# 0  05/05     Qui   34   20    Tempo nublado  cloudly_day
# 1  06/05     Sex   34   21    Tempo nublado  cloudly_day
# 2  07/05     Sáb   32   21  Chuvas esparsas         rain
# 3  08/05     Dom   33   22  Chuvas esparsas         rain
# 4  09/05     Seg   33   21  Chuvas esparsas         rain

# %%
#primeira cidade é Aparecida
dfReduzido.head(7)
# Out:
#         id                nome  microrregiao.id    microrregiao.nome  \
# 0  3502507           Aparecida            35051        Guaratinguetá
# 1  3503158              Arapeí            35052              Bananal
# 2  3503505              Areias            35052              Bananal
# 3  3504909             Bananal            35052              Bananal
# 4  3508504            Caçapava            35050  São José dos Campos
# 5  3508603  Cachoeira Paulista            35051        Guaratinguetá
# 6  3509700    Campos do Jordão            35049     Campos do Jordão
#
#    microrregiao.mesorregiao.id microrregiao.mesorregiao.nome  \
# 0                         3513      Vale do Paraíba Paulista
# 1                         3513      Vale do Paraíba Paulista
# 2                         3513      Vale do Paraíba Paulista
# 3                         3513      Vale do Paraíba Paulista
# 4                         3513      Vale do Paraíba Paulista
# 5                         3513      Vale do Paraíba Paulista
# 6                         3513      Vale do Paraíba Paulista
#
#    microrregiao.mesorregiao.UF.id microrregiao.mesorregiao.UF.sigla  \
# 0                              35                                SP
# 1                              35                                SP
# 2                              35                                SP
# 3                              35                                SP
# 4                              35                                SP
# 5                              35                                SP
# 6                              35                                SP
#
#   microrregiao.mesorregiao.UF.nome  microrregiao.mesorregiao.UF.regiao.id  \
# 0                        São Paulo                                      3
# 1                        São Paulo                                      3
# 2                        São Paulo                                      3
# 3                        São Paulo                                      3
# 4                        São Paulo                                      3
# 5                        São Paulo                                      3
# 6                        São Paulo                                      3
#
#    ... regiao-imediata.id       regiao-imediata.nome  \
# 0  ...             350052              Guaratinguetá
# 1  ...             350053                   Cruzeiro
# 2  ...             350053                   Cruzeiro
# 3  ...             350053                   Cruzeiro
# 4  ...             350049        São José dos Campos
# 5  ...             350053                   Cruzeiro
# 6  ...             350050  Taubaté - Pindamonhangaba
#
#    regiao-imediata.regiao-intermediaria.id  \
# 0                                     3511
# 1                                     3511
# 2                                     3511
# 3                                     3511
# 4                                     3511
# 5                                     3511
# 6                                     3511
#
#   regiao-imediata.regiao-intermediaria.nome  \
# 0                       São José dos Campos
# 1                       São José dos Campos
# 2                       São José dos Campos
# 3                       São José dos Campos
# 4                       São José dos Campos
# 5                       São José dos Campos
# 6                       São José dos Campos
#
#    regiao-imediata.regiao-intermediaria.UF.id  \
# 0                                          35
# 1                                          35
# 2                                          35
# 3                                          35
# 4                                          35
# 5                                          35
# 6                                          35
#
#   regiao-imediata.regiao-intermediaria.UF.sigla  \
# 0                                            SP
# 1                                            SP
# 2                                            SP
# 3                                            SP
# 4                                            SP
# 5                                            SP
# 6                                            SP
#
#    regiao-imediata.regiao-intermediaria.UF.nome  \
# 0                                     São Paulo
# 1                                     São Paulo
# 2                                     São Paulo
# 3                                     São Paulo
# 4                                     São Paulo
# 5                                     São Paulo
# 6                                     São Paulo
#
#   regiao-imediata.regiao-intermediaria.UF.regiao.id  \
# 0                                                 3
# 1                                                 3
# 2                                                 3
# 3                                                 3
# 4                                                 3
# 5                                                 3
# 6                                                 3
#
#   regiao-imediata.regiao-intermediaria.UF.regiao.sigla  \
# 0                                                 SE
# 1                                                 SE
# 2                                                 SE
# 3                                                 SE
# 4                                                 SE
# 5                                                 SE
# 6                                                 SE
#
#    regiao-imediata.regiao-intermediaria.UF.regiao.nome
# 0                                            Sudeste
# 1                                            Sudeste
# 2                                            Sudeste
# 3                                            Sudeste
# 4                                            Sudeste
# 5                                            Sudeste
# 6                                            Sudeste
#
# [7 rows x 22 columns]

# %%
dfReduzido.iloc[0]
# Out:
# id                                                                       3502507
# nome                                                                   Aparecida
# microrregiao.id                                                            35051
# microrregiao.nome                                                  Guaratinguetá
# microrregiao.mesorregiao.id                                                 3513
# microrregiao.mesorregiao.nome                           Vale do Paraíba Paulista
# microrregiao.mesorregiao.UF.id                                                35
# microrregiao.mesorregiao.UF.sigla                                             SP
# microrregiao.mesorregiao.UF.nome                                       São Paulo
# microrregiao.mesorregiao.UF.regiao.id                                          3
# microrregiao.mesorregiao.UF.regiao.sigla                                      SE
# microrregiao.mesorregiao.UF.regiao.nome                                  Sudeste
# regiao-imediata.id                                                        350052
# regiao-imediata.nome                                               Guaratinguetá
# regiao-imediata.regiao-intermediaria.id                                     3511
# regiao-imediata.regiao-intermediaria.nome                    São José dos Campos
# regiao-imediata.regiao-intermediaria.UF.id                                    35
# regiao-imediata.regiao-intermediaria.UF.sigla                                 SP
# regiao-imediata.regiao-intermediaria.UF.nome                           São Paulo
# regiao-imediata.regiao-intermediaria.UF.regiao.id                              3
# regiao-imediata.regiao-intermediaria.UF.regiao.sigla                          SE
# regiao-imediata.regiao-intermediaria.UF.regiao.nome                      Sudeste
# Name: 0, dtype: object

# %%
#Especificação: Código é o nome da cidade + id: ex = 35051Aparecida

# %%
#Não vou automatizar o processo mais uma vez, por tratar apenas 7 dados
# mas o caminho é combinar laços e as estruturas do python

# %%
nome1 = ['Aparecida','Aparecida','Aparecida','Aparecida','Aparecida']
codigo1 = ['35051Aparecida','35051Aparecida','35051Aparecida','35051Aparecida','35051Aparecida']
regiao1 = ['Guaratinguetá','Guaratinguetá','Guaratinguetá','Guaratinguetá','Guaratinguetá']
pais = ['Brasil','Brasil','Brasil','Brasil','Brasil']

# %%
#nascer do sol e por do SOl, outras condições, só consegui para o dia atual na API. O resto das utilidades exigia pagamento

# %%
#portanto, dividi em duas tabelas

# %%
df_forecast.to_csv("tabela1A.csv")

# %%
#Agora utilizarei a previsao para os próximos 5 dias de cada uma das 7 cidades com o máximo que obtive
dfA
# Out:
#     date weekday  max  min      description    condition
# 0  05/05     Qui   34   20    Tempo nublado  cloudly_day
# 1  06/05     Sex   34   21    Tempo nublado  cloudly_day
# 2  07/05     Sáb   32   21  Chuvas esparsas         rain
# 3  08/05     Dom   33   22  Chuvas esparsas         rain
# 4  09/05     Seg   33   21  Chuvas esparsas         rain

# %%
dfA['city'] = nome1
dfA['code'] = codigo1
dfA['microregion'] = regiao1
dfA['country'] = pais

# %%
dfA
# Out:
#     date weekday  max  min      description    condition       city  \
# 0  05/05     Qui   34   20    Tempo nublado  cloudly_day  Aparecida
# 1  06/05     Sex   34   21    Tempo nublado  cloudly_day  Aparecida
# 2  07/05     Sáb   32   21  Chuvas esparsas         rain  Aparecida
# 3  08/05     Dom   33   22  Chuvas esparsas         rain  Aparecida
# 4  09/05     Seg   33   21  Chuvas esparsas         rain  Aparecida
#
#              code    microregion country
# 0  35051Aparecida  Guaratinguetá  Brasil
# 1  35051Aparecida  Guaratinguetá  Brasil
# 2  35051Aparecida  Guaratinguetá  Brasil
# 3  35051Aparecida  Guaratinguetá  Brasil
# 4  35051Aparecida  Guaratinguetá  Brasil

# %%
#fazer o mesmo para os outros 7, antes de juntar os dataframes
dfReduzido.iloc[1]
# Out:
# id                                                                       3503158
# nome                                                                      Arapeí
# microrregiao.id                                                            35052
# microrregiao.nome                                                        Bananal
# microrregiao.mesorregiao.id                                                 3513
# microrregiao.mesorregiao.nome                           Vale do Paraíba Paulista
# microrregiao.mesorregiao.UF.id                                                35
# microrregiao.mesorregiao.UF.sigla                                             SP
# microrregiao.mesorregiao.UF.nome                                       São Paulo
# microrregiao.mesorregiao.UF.regiao.id                                          3
# microrregiao.mesorregiao.UF.regiao.sigla                                      SE
# microrregiao.mesorregiao.UF.regiao.nome                                  Sudeste
# regiao-imediata.id                                                        350053
# regiao-imediata.nome                                                    Cruzeiro
# regiao-imediata.regiao-intermediaria.id                                     3511
# regiao-imediata.regiao-intermediaria.nome                    São José dos Campos
# regiao-imediata.regiao-intermediaria.UF.id                                    35
# regiao-imediata.regiao-intermediaria.UF.sigla                                 SP
# regiao-imediata.regiao-intermediaria.UF.nome                           São Paulo
# regiao-imediata.regiao-intermediaria.UF.regiao.id                              3
# regiao-imediata.regiao-intermediaria.UF.regiao.sigla                          SE
# regiao-imediata.regiao-intermediaria.UF.regiao.nome                      Sudeste
# Name: 1, dtype: object

# %%
nome2=['Arapeí','Arapeí','Arapeí','Arapeí','Arapeí']
codigo2=['3503158Arapeí','3503158Arapeí','3503158Arapeí','3503158Arapeí','3503158Arapeí']
regiao2=['Bananal','Bananal','Bananal','Bananal','Bananal']

# %%
dfB['city'] = nome2
dfB['code'] = codigo2
dfB['microregion'] = regiao2
dfB['country'] = pais
dfB
# Out:
#     date weekday  max  min      description  condition    city           code  \
# 0  05/05     Qui   25   15      Tempo limpo  clear_day  Arapeí  3503158Arapeí
# 1  06/05     Sex   23   13  Chuvas esparsas       rain  Arapeí  3503158Arapeí
# 2  07/05     Sáb   21   15  Chuvas esparsas       rain  Arapeí  3503158Arapeí
# 3  08/05     Dom   21   15  Chuvas esparsas       rain  Arapeí  3503158Arapeí
# 4  09/05     Seg   23   15      Tempo limpo  clear_day  Arapeí  3503158Arapeí
#
#   microregion country
# 0     Bananal  Brasil
# 1     Bananal  Brasil
# 2     Bananal  Brasil
# 3     Bananal  Brasil
# 4     Bananal  Brasil

# %%
dfReduzido.iloc[2]
# Out:
# id                                                                       3503505
# nome                                                                      Areias
# microrregiao.id                                                            35052
# microrregiao.nome                                                        Bananal
# microrregiao.mesorregiao.id                                                 3513
# microrregiao.mesorregiao.nome                           Vale do Paraíba Paulista
# microrregiao.mesorregiao.UF.id                                                35
# microrregiao.mesorregiao.UF.sigla                                             SP
# microrregiao.mesorregiao.UF.nome                                       São Paulo
# microrregiao.mesorregiao.UF.regiao.id                                          3
# microrregiao.mesorregiao.UF.regiao.sigla                                      SE
# microrregiao.mesorregiao.UF.regiao.nome                                  Sudeste
# regiao-imediata.id                                                        350053
# regiao-imediata.nome                                                    Cruzeiro
# regiao-imediata.regiao-intermediaria.id                                     3511
# regiao-imediata.regiao-intermediaria.nome                    São José dos Campos
# regiao-imediata.regiao-intermediaria.UF.id                                    35
# regiao-imediata.regiao-intermediaria.UF.sigla                                 SP
# regiao-imediata.regiao-intermediaria.UF.nome                           São Paulo
# regiao-imediata.regiao-intermediaria.UF.regiao.id                              3
# regiao-imediata.regiao-intermediaria.UF.regiao.sigla                          SE
# regiao-imediata.regiao-intermediaria.UF.regiao.nome                      Sudeste
# Name: 2, dtype: object

# %%
nome3 = ['Areias','Areias','Areias','Areias','Areias']
codigo3 = ['3503505Areias', '3503505Areias', '3503505Areias', '3503505Areias', '3503505Areias']
regiao3 = ['Bananal','Bananal','Bananal','Bananal','Bananal']

# %%
dfC
# Out:
#     date weekday  max  min      description  condition
# 0  05/05     Qui   26   14      Tempo limpo  clear_day
# 1  06/05     Sex   24   13  Chuvas esparsas       rain
# 2  07/05     Sáb   23   17  Chuvas esparsas       rain
# 3  08/05     Dom   22   17  Chuvas esparsas       rain
# 4  09/05     Seg   24   16      Tempo limpo  clear_day

# %%
dfC['city'] = nome3
dfC['code'] = codigo3
dfC['microregion'] = regiao3
dfC['country'] = pais
dfC
# Out:
#     date weekday  max  min      description  condition    city           code  \
# 0  05/05     Qui   26   14      Tempo limpo  clear_day  Areias  3503505Areias
# 1  06/05     Sex   24   13  Chuvas esparsas       rain  Areias  3503505Areias
# 2  07/05     Sáb   23   17  Chuvas esparsas       rain  Areias  3503505Areias
# 3  08/05     Dom   22   17  Chuvas esparsas       rain  Areias  3503505Areias
# 4  09/05     Seg   24   16      Tempo limpo  clear_day  Areias  3503505Areias
#
#   microregion country
# 0     Bananal  Brasil
# 1     Bananal  Brasil
# 2     Bananal  Brasil
# 3     Bananal  Brasil
# 4     Bananal  Brasil

# %%
dfReduzido.iloc[3]
# Out:
# id                                                                       3504909
# nome                                                                     Bananal
# microrregiao.id                                                            35052
# microrregiao.nome                                                        Bananal
# microrregiao.mesorregiao.id                                                 3513
# microrregiao.mesorregiao.nome                           Vale do Paraíba Paulista
# microrregiao.mesorregiao.UF.id                                                35
# microrregiao.mesorregiao.UF.sigla                                             SP
# microrregiao.mesorregiao.UF.nome                                       São Paulo
# microrregiao.mesorregiao.UF.regiao.id                                          3
# microrregiao.mesorregiao.UF.regiao.sigla                                      SE
# microrregiao.mesorregiao.UF.regiao.nome                                  Sudeste
# regiao-imediata.id                                                        350053
# regiao-imediata.nome                                                    Cruzeiro
# regiao-imediata.regiao-intermediaria.id                                     3511
# regiao-imediata.regiao-intermediaria.nome                    São José dos Campos
# regiao-imediata.regiao-intermediaria.UF.id                                    35
# regiao-imediata.regiao-intermediaria.UF.sigla                                 SP
# regiao-imediata.regiao-intermediaria.UF.nome                           São Paulo
# regiao-imediata.regiao-intermediaria.UF.regiao.id                              3
# regiao-imediata.regiao-intermediaria.UF.regiao.sigla                          SE
# regiao-imediata.regiao-intermediaria.UF.regiao.nome                      Sudeste
# Name: 3, dtype: object

# %%
nome4 = ['Bananal','Bananal','Bananal','Bananal','Bananal']
codigo4= ['3504909Bananal', '3504909Bananal', '3504909Bananal','3504909Bananal','3504909Bananal']
regiao4= ['Bananal','Bananal','Bananal','Bananal','Bananal']

# %%
dfD['city'] = nome4
dfD['code'] = codigo4
dfD['microregion'] = regiao4
dfD['country'] = pais
dfD
# Out:
#     date weekday  max  min      description  condition     city  \
# 0  05/05     Qui   25   15      Tempo limpo  clear_day  Bananal
# 1  06/05     Sex   23   13  Chuvas esparsas       rain  Bananal
# 2  07/05     Sáb   21   15  Chuvas esparsas       rain  Bananal
# 3  08/05     Dom   21   15  Chuvas esparsas       rain  Bananal
# 4  09/05     Seg   23   15      Tempo limpo  clear_day  Bananal
#
#              code microregion country
# 0  3504909Bananal     Bananal  Brasil
# 1  3504909Bananal     Bananal  Brasil
# 2  3504909Bananal     Bananal  Brasil
# 3  3504909Bananal     Bananal  Brasil
# 4  3504909Bananal     Bananal  Brasil

# %%
dfReduzido.iloc[4]
# Out:
# id                                                                       3508504
# nome                                                                    Caçapava
# microrregiao.id                                                            35050
# microrregiao.nome                                            São José dos Campos
# microrregiao.mesorregiao.id                                                 3513
# microrregiao.mesorregiao.nome                           Vale do Paraíba Paulista
# microrregiao.mesorregiao.UF.id                                                35
# microrregiao.mesorregiao.UF.sigla                                             SP
# microrregiao.mesorregiao.UF.nome                                       São Paulo
# microrregiao.mesorregiao.UF.regiao.id                                          3
# microrregiao.mesorregiao.UF.regiao.sigla                                      SE
# microrregiao.mesorregiao.UF.regiao.nome                                  Sudeste
# regiao-imediata.id                                                        350049
# regiao-imediata.nome                                         São José dos Campos
# regiao-imediata.regiao-intermediaria.id                                     3511
# regiao-imediata.regiao-intermediaria.nome                    São José dos Campos
# regiao-imediata.regiao-intermediaria.UF.id                                    35
# regiao-imediata.regiao-intermediaria.UF.sigla                                 SP
# regiao-imediata.regiao-intermediaria.UF.nome                           São Paulo
# regiao-imediata.regiao-intermediaria.UF.regiao.id                              3
# regiao-imediata.regiao-intermediaria.UF.regiao.sigla                          SE
# regiao-imediata.regiao-intermediaria.UF.regiao.nome                      Sudeste
# Name: 4, dtype: object

# %%
nome5 = ['Caçapava','Caçapava','Caçapava','Caçapava','Caçapava']
codigo5 = ['3508504Caçapava', '3508504Caçapava', '3508504Caçapava','3508504Caçapava','3508504Caçapava']
regiao5 = ['São José dos Campos','São José dos Campos','São José dos Campos','São José dos Campos','São José dos Campos']

# %%
dfE['city'] = nome5
dfE['code'] = codigo5
dfE['microregion'] = regiao5
dfE['country'] = pais
dfE
# Out:
#     date weekday  max  min           description    condition      city  \
# 0  05/05     Qui   22   10           Tempo limpo    clear_day  Caçapava
# 1  06/05     Sex   24   14  Parcialmente nublado        cloud  Caçapava
# 2  07/05     Sáb   23   14         Tempo nublado  cloudly_day  Caçapava
# 3  08/05     Dom   23   15         Tempo nublado  cloudly_day  Caçapava
# 4  09/05     Seg   24   14         Tempo nublado  cloudly_day  Caçapava
#
#               code          microregion country
# 0  3508504Caçapava  São José dos Campos  Brasil
# 1  3508504Caçapava  São José dos Campos  Brasil
# 2  3508504Caçapava  São José dos Campos  Brasil
# 3  3508504Caçapava  São José dos Campos  Brasil
# 4  3508504Caçapava  São José dos Campos  Brasil

# %%
dfReduzido.iloc[5]
# Out:
# id                                                                       3508603
# nome                                                          Cachoeira Paulista
# microrregiao.id                                                            35051
# microrregiao.nome                                                  Guaratinguetá
# microrregiao.mesorregiao.id                                                 3513
# microrregiao.mesorregiao.nome                           Vale do Paraíba Paulista
# microrregiao.mesorregiao.UF.id                                                35
# microrregiao.mesorregiao.UF.sigla                                             SP
# microrregiao.mesorregiao.UF.nome                                       São Paulo
# microrregiao.mesorregiao.UF.regiao.id                                          3
# microrregiao.mesorregiao.UF.regiao.sigla                                      SE
# microrregiao.mesorregiao.UF.regiao.nome                                  Sudeste
# regiao-imediata.id                                                        350053
# regiao-imediata.nome                                                    Cruzeiro
# regiao-imediata.regiao-intermediaria.id                                     3511
# regiao-imediata.regiao-intermediaria.nome                    São José dos Campos
# regiao-imediata.regiao-intermediaria.UF.id                                    35
# regiao-imediata.regiao-intermediaria.UF.sigla                                 SP
# regiao-imediata.regiao-intermediaria.UF.nome                           São Paulo
# regiao-imediata.regiao-intermediaria.UF.regiao.id                              3
# regiao-imediata.regiao-intermediaria.UF.regiao.sigla                          SE
# regiao-imediata.regiao-intermediaria.UF.regiao.nome                      Sudeste
# Name: 5, dtype: object

# %%
nome6 = ['Cachoeira Paulista','Cachoeira Paulista','Cachoeira Paulista','Cachoeira Paulista','Cachoeira Paulista']
codigo6 = ['3508603Cachoeira Paulista', '3508603Cachoeira Paulista', '3508603Cachoeira Paulista','3508603Cachoeira Paulista','3508603Cachoeira Paulista']
regiao6 = ['Guaratinguetá','Guaratinguetá','Guaratinguetá','Guaratinguetá','Guaratinguetá']

# %%
dfF['city'] = nome6
dfF['code'] = codigo6
dfF['microregion'] = regiao6
dfF['country'] = pais
dfF
# Out:
#     date weekday  max  min           description    condition  \
# 0  05/05     Qui   25   12           Tempo limpo    clear_day
# 1  06/05     Sex   25   13  Parcialmente nublado  cloudly_day
# 2  07/05     Sáb   24   14         Tempo nublado  cloudly_day
# 3  08/05     Dom   24   15  Parcialmente nublado        cloud
# 4  09/05     Seg   24   15  Parcialmente nublado        cloud
#
#                  city                       code    microregion country
# 0  Cachoeira Paulista  3508603Cachoeira Paulista  Guaratinguetá  Brasil
# 1  Cachoeira Paulista  3508603Cachoeira Paulista  Guaratinguetá  Brasil
# 2  Cachoeira Paulista  3508603Cachoeira Paulista  Guaratinguetá  Brasil
# 3  Cachoeira Paulista  3508603Cachoeira Paulista  Guaratinguetá  Brasil
# 4  Cachoeira Paulista  3508603Cachoeira Paulista  Guaratinguetá  Brasil

# %%
dfReduzido.iloc[6]
# Out:
# id                                                                        3509700
# nome                                                             Campos do Jordão
# microrregiao.id                                                             35049
# microrregiao.nome                                                Campos do Jordão
# microrregiao.mesorregiao.id                                                  3513
# microrregiao.mesorregiao.nome                            Vale do Paraíba Paulista
# microrregiao.mesorregiao.UF.id                                                 35
# microrregiao.mesorregiao.UF.sigla                                              SP
# microrregiao.mesorregiao.UF.nome                                        São Paulo
# microrregiao.mesorregiao.UF.regiao.id                                           3
# microrregiao.mesorregiao.UF.regiao.sigla                                       SE
# microrregiao.mesorregiao.UF.regiao.nome                                   Sudeste
# regiao-imediata.id                                                         350050
# regiao-imediata.nome                                    Taubaté - Pindamonhangaba
# regiao-imediata.regiao-intermediaria.id                                      3511
# regiao-imediata.regiao-intermediaria.nome                     São José dos Campos
# regiao-imediata.regiao-intermediaria.UF.id                                     35
# regiao-imediata.regiao-intermediaria.UF.sigla                                  SP
# regiao-imediata.regiao-intermediaria.UF.nome                            São Paulo
# regiao-imediata.regiao-intermediaria.UF.regiao.id                               3
# regiao-imediata.regiao-intermediaria.UF.regiao.sigla                           SE
# regiao-imediata.regiao-intermediaria.UF.regiao.nome                       Sudeste
# Name: 6, dtype: object

# %%
nome7 = ['Campos do Jordão','Campos do Jordão','Campos do Jordão','Campos do Jordão','Campos do Jordão']
codigo7 = ['3509700 Campos do Jordão', '3509700 Campos do Jordão', '3509700 Campos do Jordão','3509700 Campos do Jordão','3509700 Campos do Jordão']
regiao7 = ['Campos do Jordão','Campos do Jordão','Campos do Jordão','Campos do Jordão','Campos do Jordão']

# %%
dfG['city'] = nome7
dfG['code'] = codigo7
dfG['microregion'] = regiao7
dfG['country'] = pais
dfG
# Out:
#     date weekday  max  min      description  condition              city  \
# 0  05/05     Qui   17    5      Tempo limpo  clear_day  Campos do Jordão
# 1  06/05     Sex   18    7      Tempo limpo  clear_day  Campos do Jordão
# 2  07/05     Sáb   17    9  Chuvas esparsas       rain  Campos do Jordão
# 3  08/05     Dom   17   10  Chuvas esparsas       rain  Campos do Jordão
# 4  09/05     Seg   18   10  Chuvas esparsas       rain  Campos do Jordão
#
#                        code       microregion country
# 0  3509700 Campos do Jordão  Campos do Jordão  Brasil
# 1  3509700 Campos do Jordão  Campos do Jordão  Brasil
# 2  3509700 Campos do Jordão  Campos do Jordão  Brasil
# 3  3509700 Campos do Jordão  Campos do Jordão  Brasil
# 4  3509700 Campos do Jordão  Campos do Jordão  Brasil

# %%
dfA
# Out:
#     date weekday  max  min      description    condition       city  \
# 0  05/05     Qui   34   20    Tempo nublado  cloudly_day  Aparecida
# 1  06/05     Sex   34   21    Tempo nublado  cloudly_day  Aparecida
# 2  07/05     Sáb   32   21  Chuvas esparsas         rain  Aparecida
# 3  08/05     Dom   33   22  Chuvas esparsas         rain  Aparecida
# 4  09/05     Seg   33   21  Chuvas esparsas         rain  Aparecida
#
#              code    microregion country
# 0  35051Aparecida  Guaratinguetá  Brasil
# 1  35051Aparecida  Guaratinguetá  Brasil
# 2  35051Aparecida  Guaratinguetá  Brasil
# 3  35051Aparecida  Guaratinguetá  Brasil
# 4  35051Aparecida  Guaratinguetá  Brasil

# %%
dfB
# Out:
#     date weekday  max  min      description  condition    city           code  \
# 0  05/05     Qui   25   15      Tempo limpo  clear_day  Arapeí  3503158Arapeí
# 1  06/05     Sex   23   13  Chuvas esparsas       rain  Arapeí  3503158Arapeí
# 2  07/05     Sáb   21   15  Chuvas esparsas       rain  Arapeí  3503158Arapeí
# 3  08/05     Dom   21   15  Chuvas esparsas       rain  Arapeí  3503158Arapeí
# 4  09/05     Seg   23   15      Tempo limpo  clear_day  Arapeí  3503158Arapeí
#
#   microregion country
# 0     Bananal  Brasil
# 1     Bananal  Brasil
# 2     Bananal  Brasil
# 3     Bananal  Brasil
# 4     Bananal  Brasil

# %%
dfC
# Out:
#     date weekday  max  min      description  condition    city           code  \
# 0  05/05     Qui   26   14      Tempo limpo  clear_day  Areias  3503505Areias
# 1  06/05     Sex   24   13  Chuvas esparsas       rain  Areias  3503505Areias
# 2  07/05     Sáb   23   17  Chuvas esparsas       rain  Areias  3503505Areias
# 3  08/05     Dom   22   17  Chuvas esparsas       rain  Areias  3503505Areias
# 4  09/05     Seg   24   16      Tempo limpo  clear_day  Areias  3503505Areias
#
#   microregion country
# 0     Bananal  Brasil
# 1     Bananal  Brasil
# 2     Bananal  Brasil
# 3     Bananal  Brasil
# 4     Bananal  Brasil

# %%
dfD
# Out:
#     date weekday  max  min      description  condition     city  \
# 0  05/05     Qui   25   15      Tempo limpo  clear_day  Bananal
# 1  06/05     Sex   23   13  Chuvas esparsas       rain  Bananal
# 2  07/05     Sáb   21   15  Chuvas esparsas       rain  Bananal
# 3  08/05     Dom   21   15  Chuvas esparsas       rain  Bananal
# 4  09/05     Seg   23   15      Tempo limpo  clear_day  Bananal
#
#              code microregion country
# 0  3504909Bananal     Bananal  Brasil
# 1  3504909Bananal     Bananal  Brasil
# 2  3504909Bananal     Bananal  Brasil
# 3  3504909Bananal     Bananal  Brasil
# 4  3504909Bananal     Bananal  Brasil

# %%
dfE
# Out:
#     date weekday  max  min           description    condition      city  \
# 0  05/05     Qui   22   10           Tempo limpo    clear_day  Caçapava
# 1  06/05     Sex   24   14  Parcialmente nublado        cloud  Caçapava
# 2  07/05     Sáb   23   14         Tempo nublado  cloudly_day  Caçapava
# 3  08/05     Dom   23   15         Tempo nublado  cloudly_day  Caçapava
# 4  09/05     Seg   24   14         Tempo nublado  cloudly_day  Caçapava
#
#               code          microregion country
# 0  3508504Caçapava  São José dos Campos  Brasil
# 1  3508504Caçapava  São José dos Campos  Brasil
# 2  3508504Caçapava  São José dos Campos  Brasil
# 3  3508504Caçapava  São José dos Campos  Brasil
# 4  3508504Caçapava  São José dos Campos  Brasil

# %%
dfF
# Out:
#     date weekday  max  min           description    condition  \
# 0  05/05     Qui   25   12           Tempo limpo    clear_day
# 1  06/05     Sex   25   13  Parcialmente nublado  cloudly_day
# 2  07/05     Sáb   24   14         Tempo nublado  cloudly_day
# 3  08/05     Dom   24   15  Parcialmente nublado        cloud
# 4  09/05     Seg   24   15  Parcialmente nublado        cloud
#
#                  city                       code    microregion country
# 0  Cachoeira Paulista  3508603Cachoeira Paulista  Guaratinguetá  Brasil
# 1  Cachoeira Paulista  3508603Cachoeira Paulista  Guaratinguetá  Brasil
# 2  Cachoeira Paulista  3508603Cachoeira Paulista  Guaratinguetá  Brasil
# 3  Cachoeira Paulista  3508603Cachoeira Paulista  Guaratinguetá  Brasil
# 4  Cachoeira Paulista  3508603Cachoeira Paulista  Guaratinguetá  Brasil

# %%
dfG
# Out:
#     date weekday  max  min      description  condition              city  \
# 0  05/05     Qui   17    5      Tempo limpo  clear_day  Campos do Jordão
# 1  06/05     Sex   18    7      Tempo limpo  clear_day  Campos do Jordão
# 2  07/05     Sáb   17    9  Chuvas esparsas       rain  Campos do Jordão
# 3  08/05     Dom   17   10  Chuvas esparsas       rain  Campos do Jordão
# 4  09/05     Seg   18   10  Chuvas esparsas       rain  Campos do Jordão
#
#                        code       microregion country
# 0  3509700 Campos do Jordão  Campos do Jordão  Brasil
# 1  3509700 Campos do Jordão  Campos do Jordão  Brasil
# 2  3509700 Campos do Jordão  Campos do Jordão  Brasil
# 3  3509700 Campos do Jordão  Campos do Jordão  Brasil
# 4  3509700 Campos do Jordão  Campos do Jordão  Brasil

# %%
Tabela1 = pd.concat([dfA,dfB,dfC,dfD,dfE,dfF,dfG])

# %%
Tabela1.to_csv("Tabela1.csv")

# %%
#CRIAÇÃO DAS TEMP VIEWS

#TRABALHAR COM DATAFRAMES DO SPARK

Tabela1
# Out:
#     date weekday  max  min           description    condition  \
# 0  05/05     Qui   34   20         Tempo nublado  cloudly_day
# 1  06/05     Sex   34   21         Tempo nublado  cloudly_day
# 2  07/05     Sáb   32   21       Chuvas esparsas         rain
# 3  08/05     Dom   33   22       Chuvas esparsas         rain
# 4  09/05     Seg   33   21       Chuvas esparsas         rain
# 0  05/05     Qui   25   15           Tempo limpo    clear_day
# 1  06/05     Sex   23   13       Chuvas esparsas         rain
# 2  07/05     Sáb   21   15       Chuvas esparsas         rain
# 3  08/05     Dom   21   15       Chuvas esparsas         rain
# 4  09/05     Seg   23   15           Tempo limpo    clear_day
# 0  05/05     Qui   26   14           Tempo limpo    clear_day
# 1  06/05     Sex   24   13       Chuvas esparsas         rain
# 2  07/05     Sáb   23   17       Chuvas esparsas         rain
# 3  08/05     Dom   22   17       Chuvas esparsas         rain
# 4  09/05     Seg   24   16           Tempo limpo    clear_day
# 0  05/05     Qui   25   15           Tempo limpo    clear_day
# 1  06/05     Sex   23   13       Chuvas esparsas         rain
# 2  07/05     Sáb   21   15       Chuvas esparsas         rain
# 3  08/05     Dom   21   15       Chuvas esparsas         rain
# 4  09/05     Seg   23   15           Tempo limpo    clear_day
# 0  05/05     Qui   22   10           Tempo limpo    clear_day
# 1  06/05     Sex   24   14  Parcialmente nublado        cloud
# 2  07/05     Sáb   23   14         Tempo nublado  cloudly_day
# 3  08/05     Dom   23   15         Tempo nublado  cloudly_day
# 4  09/05     Seg   24   14         Tempo nublado  cloudly_day
# 0  05/05     Qui   25   12           Tempo limpo    clear_day
# 1  06/05     Sex   25   13  Parcialmente nublado  cloudly_day
# 2  07/05     Sáb   24   14         Tempo nublado  cloudly_day
# 3  08/05     Dom   24   15  Parcialmente nublado        cloud
# 4  09/05     Seg   24   15  Parcialmente nublado        cloud
# 0  05/05     Qui   17    5           Tempo limpo    clear_day
# 1  06/05     Sex   18    7           Tempo limpo    clear_day
# 2  07/05     Sáb   17    9       Chuvas esparsas         rain
# 3  08/05     Dom   17   10       Chuvas esparsas         rain
# 4  09/05     Seg   18   10       Chuvas esparsas         rain
#
#                  city                       code          microregion country
# 0           Aparecida             35051Aparecida        Guaratinguetá  Brasil
# 1           Aparecida             35051Aparecida        Guaratinguetá  Brasil
# 2           Aparecida             35051Aparecida        Guaratinguetá  Brasil
# 3           Aparecida             35051Aparecida        Guaratinguetá  Brasil
# 4           Aparecida             35051Aparecida        Guaratinguetá  Brasil
# 0              Arapeí              3503158Arapeí              Bananal  Brasil
# 1              Arapeí              3503158Arapeí              Bananal  Brasil
# 2              Arapeí              3503158Arapeí              Bananal  Brasil
# 3              Arapeí              3503158Arapeí              Bananal  Brasil
# 4              Arapeí              3503158Arapeí              Bananal  Brasil
# 0              Areias              3503505Areias              Bananal  Brasil
# 1              Areias              3503505Areias              Bananal  Brasil
# 2              Areias              3503505Areias              Bananal  Brasil
# 3              Areias              3503505Areias              Bananal  Brasil
# 4              Areias              3503505Areias              Bananal  Brasil
# 0             Bananal             3504909Bananal              Bananal  Brasil
# 1             Bananal             3504909Bananal              Bananal  Brasil
# 2             Bananal             3504909Bananal              Bananal  Brasil
# 3             Bananal             3504909Bananal              Bananal  Brasil
# 4             Bananal             3504909Bananal              Bananal  Brasil
# 0            Caçapava            3508504Caçapava  São José dos Campos  Brasil
# 1            Caçapava            3508504Caçapava  São José dos Campos  Brasil
# 2            Caçapava            3508504Caçapava  São José dos Campos  Brasil
# 3            Caçapava            3508504Caçapava  São José dos Campos  Brasil
# 4            Caçapava            3508504Caçapava  São José dos Campos  Brasil
# 0  Cachoeira Paulista  3508603Cachoeira Paulista        Guaratinguetá  Brasil
# 1  Cachoeira Paulista  3508603Cachoeira Paulista        Guaratinguetá  Brasil
# 2  Cachoeira Paulista  3508603Cachoeira Paulista        Guaratinguetá  Brasil
# 3  Cachoeira Paulista  3508603Cachoeira Paulista        Guaratinguetá  Brasil
# 4  Cachoeira Paulista  3508603Cachoeira Paulista        Guaratinguetá  Brasil
# 0    Campos do Jordão   3509700 Campos do Jordão     Campos do Jordão  Brasil
# 1    Campos do Jordão   3509700 Campos do Jordão     Campos do Jordão  Brasil
# 2    Campos do Jordão   3509700 Campos do Jordão     Campos do Jordão  Brasil
# 3    Campos do Jordão   3509700 Campos do Jordão     Campos do Jordão  Brasil
# 4    Campos do Jordão   3509700 Campos do Jordão     Campos do Jordão  Brasil

# %%
sparkdf1 = spark.createDataFrame(dfReduzido)

# %%
sparkdf1.show()
# Out:
# +-------+------------------+---------------+-------------------+---------------------------+-----------------------------+------------------------------+---------------------------------+--------------------------------+-------------------------------------+----------------------------------------+---------------------------------------+------------------+--------------------+---------------------------------------+-----------------------------------------+------------------------------------------+---------------------------------------------+--------------------------------------------+-------------------------------------------------+----------------------------------------------------+---------------------------------------------------+
# |     id|              nome|microrregiao.id|  microrregiao.nome|microrregiao.mesorregiao.id|microrregiao.mesorregiao.nome|microrregiao.mesorregiao.UF.id|microrregiao.mesorregiao.UF.sigla|microrregiao.mesorregiao.UF.nome|microrregiao.mesorregiao.UF.regiao.id|microrregiao.mesorregiao.UF.regiao.sigla|microrregiao.mesorregiao.UF.regiao.nome|regiao-imediata.id|regiao-imediata.nome|regiao-imediata.regiao-intermediaria.id|regiao-imediata.regiao-intermediaria.nome|regiao-imediata.regiao-intermediaria.UF.id|regiao-imediata.regiao-intermediaria.UF.sigla|regiao-imediata.regiao-intermediaria.UF.nome|regiao-imediata.regiao-intermediaria.UF.regiao.id|regiao-imediata.regiao-intermediaria.UF.regiao.sigla|regiao-imediata.regiao-intermediaria.UF.regiao.nome|
# +-------+------------------+---------------+-------------------+---------------------------+-----------------------------+------------------------------+---------------------------------+--------------------------------+-------------------------------------+----------------------------------------+---------------------------------------+------------------+--------------------+---------------------------------------+-----------------------------------------+------------------------------------------+---------------------------------------------+--------------------------------------------+-------------------------------------------------+----------------------------------------------------+---------------------------------------------------+
# |3502507|         Aparecida|          35051|      Guaratinguetá|                       3513|         Vale do Paraíba P...|                            35|                               SP|                       São Paulo|                                    3|                                      SE|                                Sudeste|            350052|       Guaratinguetá|                                   3511|                      São José dos Campos|                                        35|                                           SP|                                   São Paulo|                                                3|                                                  SE|                                            Sudeste|
# |3503158|            Arapeí|          35052|            Bananal|                       3513|         Vale do Paraíba P...|                            35|                               SP|                       São Paulo|                                    3|                                      SE|                                Sudeste|            350053|            Cruzeiro|                                   3511|                      São José dos Campos|                                        35|                                           SP|                                   São Paulo|                                                3|                                                  SE|                                            Sudeste|
# |3503505|            Areias|          35052|            Bananal|                       3513|         Vale do Paraíba P...|                            35|                               SP|                       São Paulo|                                    3|                                      SE|                                Sudeste|            350053|            Cruzeiro|                                   3511|                      São José dos Campos|                                        35|                                           SP|                                   São Paulo|                                                3|                                                  SE|                                            Sudeste|
# |3504909|           Bananal|          35052|            Bananal|                       3513|         Vale do Paraíba P...|                            35|                               SP|                       São Paulo|                                    3|                                      SE|                                Sudeste|            350053|            Cruzeiro|                                   3511|                      São José dos Campos|                                        35|                                           SP|                                   São Paulo|                                                3|                                                  SE|                                            Sudeste|
# |3508504|          Caçapava|          35050|São José dos Campos|                       3513|         Vale do Paraíba P...|                            35|                               SP|                       São Paulo|                                    3|                                      SE|                                Sudeste|            350049| São José dos Campos|                                   3511|                      São José dos Campos|                                        35|                                           SP|                                   São Paulo|                                                3|                                                  SE|                                            Sudeste|
# |3508603|Cachoeira Paulista|          35051|      Guaratinguetá|                       3513|         Vale do Paraíba P...|                            35|                               SP|                       São Paulo|                                    3|                                      SE|                                Sudeste|            350053|            Cruzeiro|                                   3511|                      São José dos Campos|                                        35|                                           SP|                                   São Paulo|                                                3|                                                  SE|                                            Sudeste|
# |3509700|  Campos do Jordão|          35049|   Campos do Jordão|                       3513|         Vale do Paraíba P...|                            35|                               SP|                       São Paulo|                                    3|                                      SE|                                Sudeste|            350050|Taubaté - Pindamo...|                                   3511|                      São José dos Campos|                                        35|                                           SP|                                   São Paulo|                                                3|                                                  SE|                                            Sudeste|
# +-------+------------------+---------------+-------------------+---------------------------+-----------------------------+------------------------------+---------------------------------+--------------------------------+-------------------------------------+----------------------------------------+---------------------------------------+------------------+--------------------+---------------------------------------+-----------------------------------------+------------------------------------------+---------------------------------------------+--------------------------------------------+-------------------------------------------------+----------------------------------------------------+---------------------------------------------------+

# %%
sparkdf2 = spark.createDataFrame(Tabela1)

# %%
sparkdf2.head(3)
# Out:
# [Row(date='05/05', weekday='Qui', max=34, min=20, description='Tempo nublado', condition='cloudly_day', city='Aparecida', code='35051Aparecida', microregion='Guaratinguetá', country='Brasil'),
#  Row(date='06/05', weekday='Sex', max=34, min=21, description='Tempo nublado', condition='cloudly_day', city='Aparecida', code='35051Aparecida', microregion='Guaratinguetá', country='Brasil'),
#  Row(date='07/05', weekday='Sáb', max=32, min=21, description='Chuvas esparsas', condition='rain', city='Aparecida', code='35051Aparecida', microregion='Guaratinguetá', country='Brasil')]

# %%
sparkdf2.columns
# Out:
# ['date',
#  'weekday',
#  'max',
#  'min',
#  'description',
#  'condition',
#  'city',
#  'code',
#  'microregion',
#  'country']

# %%
sparkdf1.createOrReplaceTempView("Cities")

# %%
sparkdf2.createOrReplaceTempView("Forecast")

# %%
sqlDF1 = spark.sql("Select weekday,date from Forecast where condition = 'rain'" )
# dias com chuva

# %%
sqlDF1.show()
# Out:
# +-------+-----+
# |weekday| date|
# +-------+-----+
# |    Sáb|07/05|
# |    Dom|08/05|
# |    Seg|09/05|
# |    Sex|06/05|
# |    Sáb|07/05|
# |    Dom|08/05|
# |    Sex|06/05|
# |    Sáb|07/05|
# |    Dom|08/05|
# |    Sex|06/05|
# |    Sáb|07/05|
# |    Dom|08/05|
# |    Sáb|07/05|
# |    Dom|08/05|
# |    Seg|09/05|
# +-------+-----+

# %%
#dias sem chuva 
sqlDF2 = spark.sql("Select weekday,date from Forecast where condition != 'rain'" )
# dias com chuva

# %%
sqlDF2.show()
# Out:
# +-------+-----+
# |weekday| date|
# +-------+-----+
# |    Qui|05/05|
# |    Sex|06/05|
# |    Qui|05/05|
# |    Seg|09/05|
# |    Qui|05/05|
# |    Seg|09/05|
# |    Qui|05/05|
# |    Seg|09/05|
# |    Qui|05/05|
# |    Sex|06/05|
# |    Sáb|07/05|
# |    Dom|08/05|
# |    Seg|09/05|
# |    Qui|05/05|
# |    Sex|06/05|
# |    Sáb|07/05|
# |    Dom|08/05|
# |    Seg|09/05|
# |    Qui|05/05|
# |    Sex|06/05|
# +-------+-----+

# %%
sqlDF3 = spark.sql("Select city,count(*) from Forecast where condition = 'rain' group by city  " )

# %%
sqlDF3.show()
# Out:
# +----------------+--------+
# |            city|count(1)|
# +----------------+--------+
# |       Aparecida|       3|
# |          Arapeí|       3|
# |Campos do Jordão|       3|
# |         Bananal|       3|
# |          Areias|       3|
# +----------------+--------+

# %%
sqlDF4 = spark.sql("Select count(weekday) from Forecast where condition = 'rain'") ##numero de dias chuvosos

# %%
sqlDF4.show()
# Out:
# +--------------+
# |count(weekday)|
# +--------------+
# |            15|
# +--------------+

# %%
sqlDF5 = spark.sql("Select count(weekday)  from Forecast where condition != 'rain'") ##numero de dias nao chuvosos

# %%
sqlDF5.show()
# Out:
# +--------------+
# |count(weekday)|
# +--------------+
# |            20|
# +--------------+

# %%
##ESSAS QUERIES FORAM APENAS TESTES PESSOAIS, AGORA CRIEMOS A TABELA 2
## EM UM BANCO SQL SERVER, EU ARMAZENARIA DUAS CONSULTAS EM TABELAS TEMPORÁRIAS DISTINTAS, E DEPOIS APLICARIA O LEFT JOIN
##AQUI O PROCEDIMENTO É SIMILAR, MAS OS DATAFRAMES CRIADOS PELO SQL SERÃO AS TABELAS TEMPORARIAS
##PEDE-SE: FILTRAR PELA DATA E CONSTRUIR UM FRAME PARA CADA UMA
##subquery = locais sem chuva

sqlTEMP1 = spark.sql("Select date, city, (select count(*) from ForeCast where condition != 'rain' and date ='05/05')  from ForeCast where condition != 'rain' and date='05/05' group by city, date")

# %%
sqlTEMP1.show()
# Out:
# +-----+------------------+----------------+
# | date|              city|scalarsubquery()|
# +-----+------------------+----------------+
# |05/05|  Campos do Jordão|               7|
# |05/05|          Caçapava|               7|
# |05/05|            Arapeí|               7|
# |05/05|Cachoeira Paulista|               7|
# |05/05|           Bananal|               7|
# |05/05|         Aparecida|               7|
# |05/05|            Areias|               7|
# +-----+------------------+----------------+

# %%
##nao choveu em nenhum lugar, logo a query para = rain será vazia
sqlTEMP2 = spark.sql("Select date, city, (select count(*) from ForeCast where condition = 'rain' and date ='05/05')  from ForeCast where condition = 'rain' and date='05/05' group by city, date")

# %%
sqlTEMP2.show()
# Out:
# +----+----+----------------+
# |date|city|scalarsubquery()|
# +----+----+----------------+
# +----+----+----------------+

# %%
sqlTEMP1 = sqlTEMP1.withColumnRenamed('scalarsubquery()', 'Total of places without rain')

# %%
sqlTEMP1.show()
# Out:
# +-----+------------------+----------------------------+
# | date|              city|Total of places without rain|
# +-----+------------------+----------------------------+
# |05/05|  Campos do Jordão|                           7|
# |05/05|          Caçapava|                           7|
# |05/05|            Arapeí|                           7|
# |05/05|Cachoeira Paulista|                           7|
# |05/05|           Bananal|                           7|
# |05/05|         Aparecida|                           7|
# |05/05|            Areias|                           7|
# +-----+------------------+----------------------------+

# %%
sqlTEMP2 = sqlTEMP2.withColumnRenamed('scalarsubquery()', 'Total of places with rain')

# %%
sqlTEMP2.show()
# Out:
# +----+----+-------------------------+
# |date|city|Total of places with rain|
# +----+----+-------------------------+
# +----+----+-------------------------+

# %%
sqlTEMP1.createOrReplaceTempView("TEMP1")
sqlTEMP2.createOrReplaceTempView("TEMP2")

# %%
# nao há como fazer join se temp2 nao tem nada, entao, acrescentarei 0 a uma tabela como total de locais com cbuva

# %%
sqlTEMP1 = spark.sql("Select date, city, (select count(*) from ForeCast where condition != 'rain' and date ='05/05'), (select 0)  from ForeCast where condition != 'rain' and date='05/05' group by city, date")

# %%
sqlTEMP1.show()
# Out:
# +-----+------------------+----------------+----------------+
# | date|              city|scalarsubquery()|scalarsubquery()|
# +-----+------------------+----------------+----------------+
# |05/05|  Campos do Jordão|               7|               0|
# |05/05|          Caçapava|               7|               0|
# |05/05|            Arapeí|               7|               0|
# |05/05|Cachoeira Paulista|               7|               0|
# |05/05|           Bananal|               7|               0|
# |05/05|         Aparecida|               7|               0|
# |05/05|            Areias|               7|               0|
# +-----+------------------+----------------+----------------+

# %%
sqlTEMP1 = sqlTEMP1.toDF(*("Data", "Cidade", "Locais sem chuva", "Locais com chuva"))

# %%
sqlTEMP1.show()
# Out:
# +-----+------------------+----------------+----------------+
# | Data|            Cidade|Locais sem chuva|Locais com chuva|
# +-----+------------------+----------------+----------------+
# |05/05|  Campos do Jordão|               7|               0|
# |05/05|          Caçapava|               7|               0|
# |05/05|            Arapeí|               7|               0|
# |05/05|Cachoeira Paulista|               7|               0|
# |05/05|           Bananal|               7|               0|
# |05/05|         Aparecida|               7|               0|
# |05/05|            Areias|               7|               0|
# +-----+------------------+----------------+----------------+

# %%
dfFinal1 = sqlTEMP1

# %%
#Agora façamos o mesmo para a data 06/05
sqlTEMP1 = spark.sql("Select date, city, (select count(*) from ForeCast where condition != 'rain' and date ='06/05')  from ForeCast where condition != 'rain' and date='06/05' group by city, date")

# %%
sqlTEMP1.show()
# Out:
# +-----+------------------+----------------+
# | date|              city|scalarsubquery()|
# +-----+------------------+----------------+
# |06/05|Cachoeira Paulista|               4|
# |06/05|         Aparecida|               4|
# |06/05|          Caçapava|               4|
# |06/05|  Campos do Jordão|               4|
# +-----+------------------+----------------+

# %%
sqlTEMP1 = sqlTEMP1.toDF(*("A", "B", "C")) #só para facilitar o trabalho

# %%
#chuva no dia 6
sqlTEMP2 = spark.sql("Select date, city, (select count(*) from ForeCast where condition = 'rain' and date ='06/05')  from ForeCast where condition = 'rain' and date='06/05' group by city, date")

# %%
sqlTEMP2.show()
# Out:
# +-----+-------+----------------+
# | date|   city|scalarsubquery()|
# +-----+-------+----------------+
# |06/05| Arapeí|               3|
# |06/05|Bananal|               3|
# |06/05| Areias|               3|
# +-----+-------+----------------+

# %%
sqlTEMP2 = sqlTEMP2.toDF(*("A", "B", "C"))

# %%
# em vez de inner, left e outros joins, é mais interessante aproveitar a estrutura de dataframe e trabalahr com elas
# evitando criar excessivamente temp views

# %%
sqlTEMP1 = spark.sql("Select date, city, (select count(*) from ForeCast where condition != 'rain' and date ='06/05'), (select count(*) from ForeCast where condition = 'rain' and date ='06/05'), (select 'NAO CHOVEU')  from ForeCast where condition != 'rain' and date='06/05' group by city, date")

# %%
sqlTEMP1.show()
# Out:
# +-----+------------------+----------------+----------------+----------------+
# | date|              city|scalarsubquery()|scalarsubquery()|scalarsubquery()|
# +-----+------------------+----------------+----------------+----------------+
# |06/05|Cachoeira Paulista|               4|               3|      NAO CHOVEU|
# |06/05|         Aparecida|               4|               3|      NAO CHOVEU|
# |06/05|          Caçapava|               4|               3|      NAO CHOVEU|
# |06/05|  Campos do Jordão|               4|               3|      NAO CHOVEU|
# +-----+------------------+----------------+----------------+----------------+

# %%
sqlTEMP2 = spark.sql("Select date, city, (select count(*) from ForeCast where condition != 'rain' and date ='06/05'), (select count(*) from ForeCast where condition = 'rain' and date ='06/05'), (select 'CHOVEU')  from ForeCast where condition = 'rain' and date='06/05' group by city, date")

# %%
sqlTEMP2.show()
# Out:
# +-----+-------+----------------+----------------+----------------+
# | date|   city|scalarsubquery()|scalarsubquery()|scalarsubquery()|
# +-----+-------+----------------+----------------+----------------+
# |06/05| Arapeí|               4|               3|          CHOVEU|
# |06/05|Bananal|               4|               3|          CHOVEU|
# |06/05| Areias|               4|               3|          CHOVEU|
# +-----+-------+----------------+----------------+----------------+

# %%
dfFinal2 = sqlTEMP1.union(sqlTEMP2)

# %%
dfFinal2.show()
# Out:
# +-----+------------------+----------------+----------------+----------------+
# | date|              city|scalarsubquery()|scalarsubquery()|scalarsubquery()|
# +-----+------------------+----------------+----------------+----------------+
# |06/05|Cachoeira Paulista|               4|               3|      NAO CHOVEU|
# |06/05|         Aparecida|               4|               3|      NAO CHOVEU|
# |06/05|          Caçapava|               4|               3|      NAO CHOVEU|
# |06/05|  Campos do Jordão|               4|               3|      NAO CHOVEU|
# |06/05|            Arapeí|               4|               3|          CHOVEU|
# |06/05|           Bananal|               4|               3|          CHOVEU|
# |06/05|            Areias|               4|               3|          CHOVEU|
# +-----+------------------+----------------+----------------+----------------+

# %%
dfFinal1.show()
# Out:
# +-----+------------------+----------------+----------------+
# | Data|            Cidade|Locais sem chuva|Locais com chuva|
# +-----+------------------+----------------+----------------+
# |05/05|  Campos do Jordão|               7|               0|
# |05/05|          Caçapava|               7|               0|
# |05/05|            Arapeí|               7|               0|
# |05/05|Cachoeira Paulista|               7|               0|
# |05/05|           Bananal|               7|               0|
# |05/05|         Aparecida|               7|               0|
# |05/05|            Areias|               7|               0|
# +-----+------------------+----------------+----------------+

# %%
#vamos fazer o mesmo com dfFinal1
sqlTEMP1 = spark.sql("Select date, city, (select count(*) from ForeCast where condition != 'rain' and date ='05/05'), (select count(*) from ForeCast where condition = 'rain' and date ='05/05'), (select 'NAO CHOVEU')  from ForeCast where condition != 'rain' and date='05/05' group by city, date")

# %%
dfFinal1 = sqlTEMP1
dfFinal1.show()
# Out:
# +-----+------------------+----------------+----------------+----------------+
# | date|              city|scalarsubquery()|scalarsubquery()|scalarsubquery()|
# +-----+------------------+----------------+----------------+----------------+
# |05/05|  Campos do Jordão|               7|               0|      NAO CHOVEU|
# |05/05|          Caçapava|               7|               0|      NAO CHOVEU|
# |05/05|            Arapeí|               7|               0|      NAO CHOVEU|
# |05/05|Cachoeira Paulista|               7|               0|      NAO CHOVEU|
# |05/05|           Bananal|               7|               0|      NAO CHOVEU|
# |05/05|         Aparecida|               7|               0|      NAO CHOVEU|
# |05/05|            Areias|               7|               0|      NAO CHOVEU|
# +-----+------------------+----------------+----------------+----------------+

# %%
# para o dia 07/05
sqlTEMP1 = spark.sql("Select date, city, (select count(*) from ForeCast where condition != 'rain' and date ='07/05'), (select count(*) from ForeCast where condition = 'rain' and date ='07/05'), (select 'NAO CHOVEU')  from ForeCast where condition != 'rain' and date='07/05' group by city, date")

# %%
sqlTEMP1.show()
# Out:
# +-----+------------------+----------------+----------------+----------------+
# | date|              city|scalarsubquery()|scalarsubquery()|scalarsubquery()|
# +-----+------------------+----------------+----------------+----------------+
# |07/05|          Caçapava|               2|               5|      NAO CHOVEU|
# |07/05|Cachoeira Paulista|               2|               5|      NAO CHOVEU|
# +-----+------------------+----------------+----------------+----------------+

# %%
sqlTEMP2 = spark.sql("Select date, city, (select count(*) from ForeCast where condition != 'rain' and date ='07/05'), (select count(*) from ForeCast where condition = 'rain' and date ='07/05'), (select 'CHOVEU')  from ForeCast where condition = 'rain' and date='07/05' group by city, date")
sqlTEMP2.show()
# Out:
# +-----+----------------+----------------+----------------+----------------+
# | date|            city|scalarsubquery()|scalarsubquery()|scalarsubquery()|
# +-----+----------------+----------------+----------------+----------------+
# |07/05|          Arapeí|               2|               5|          CHOVEU|
# |07/05|         Bananal|               2|               5|          CHOVEU|
# |07/05|Campos do Jordão|               2|               5|          CHOVEU|
# |07/05|          Areias|               2|               5|          CHOVEU|
# |07/05|       Aparecida|               2|               5|          CHOVEU|
# +-----+----------------+----------------+----------------+----------------+

# %%
dfFinal3 = sqlTEMP1.union(sqlTEMP2)

# %%
dfFinal3.show()
# Out:
# +-----+------------------+----------------+----------------+----------------+
# | date|              city|scalarsubquery()|scalarsubquery()|scalarsubquery()|
# +-----+------------------+----------------+----------------+----------------+
# |07/05|          Caçapava|               2|               5|      NAO CHOVEU|
# |07/05|Cachoeira Paulista|               2|               5|      NAO CHOVEU|
# |07/05|            Arapeí|               2|               5|          CHOVEU|
# |07/05|           Bananal|               2|               5|          CHOVEU|
# |07/05|  Campos do Jordão|               2|               5|          CHOVEU|
# |07/05|            Areias|               2|               5|          CHOVEU|
# |07/05|         Aparecida|               2|               5|          CHOVEU|
# +-----+------------------+----------------+----------------+----------------+

# %%
#Para o dia 08/05
sqlTEMP1 = spark.sql("Select date, city, (select count(*) from ForeCast where condition != 'rain' and date ='08/05'), (select count(*) from ForeCast where condition = 'rain' and date ='08/05'), (select 'NAO CHOVEU')  from ForeCast where condition != 'rain' and date='08/05' group by city, date")

# %%
sqlTEMP1.show()
# Out:
# +-----+------------------+----------------+----------------+----------------+
# | date|              city|scalarsubquery()|scalarsubquery()|scalarsubquery()|
# +-----+------------------+----------------+----------------+----------------+
# |08/05|          Caçapava|               2|               5|      NAO CHOVEU|
# |08/05|Cachoeira Paulista|               2|               5|      NAO CHOVEU|
# +-----+------------------+----------------+----------------+----------------+

# %%
sqlTEMP2 = spark.sql("Select date, city, (select count(*) from ForeCast where condition != 'rain' and date ='08/05'), (select count(*) from ForeCast where condition = 'rain' and date ='08/05'), (select 'CHOVEU')  from ForeCast where condition = 'rain' and date='08/05' group by city, date")
sqlTEMP2.show()
# Out:
# +-----+----------------+----------------+----------------+----------------+
# | date|            city|scalarsubquery()|scalarsubquery()|scalarsubquery()|
# +-----+----------------+----------------+----------------+----------------+
# |08/05|         Bananal|               2|               5|          CHOVEU|
# |08/05|          Arapeí|               2|               5|          CHOVEU|
# |08/05|       Aparecida|               2|               5|          CHOVEU|
# |08/05|          Areias|               2|               5|          CHOVEU|
# |08/05|Campos do Jordão|               2|               5|          CHOVEU|
# +-----+----------------+----------------+----------------+----------------+

# %%
dfFinal4 = sqlTEMP1.union(sqlTEMP2)
dfFinal4.show()
# Out:
# +-----+------------------+----------------+----------------+----------------+
# | date|              city|scalarsubquery()|scalarsubquery()|scalarsubquery()|
# +-----+------------------+----------------+----------------+----------------+
# |08/05|          Caçapava|               2|               5|      NAO CHOVEU|
# |08/05|Cachoeira Paulista|               2|               5|      NAO CHOVEU|
# |08/05|           Bananal|               2|               5|          CHOVEU|
# |08/05|            Arapeí|               2|               5|          CHOVEU|
# |08/05|         Aparecida|               2|               5|          CHOVEU|
# |08/05|            Areias|               2|               5|          CHOVEU|
# |08/05|  Campos do Jordão|               2|               5|          CHOVEU|
# +-----+------------------+----------------+----------------+----------------+

# %%
#09/05
sqlTEMP1 = spark.sql("Select date, city, (select count(*) from ForeCast where condition != 'rain' and date ='09/05'), (select count(*) from ForeCast where condition = 'rain' and date ='09/05'), (select 'NAO CHOVEU')  from ForeCast where condition != 'rain' and date='09/05' group by city, date")
sqlTEMP1.show()
# Out:
# +-----+------------------+----------------+----------------+----------------+
# | date|              city|scalarsubquery()|scalarsubquery()|scalarsubquery()|
# +-----+------------------+----------------+----------------+----------------+
# |09/05|Cachoeira Paulista|               5|               2|      NAO CHOVEU|
# |09/05|            Areias|               5|               2|      NAO CHOVEU|
# |09/05|          Caçapava|               5|               2|      NAO CHOVEU|
# |09/05|           Bananal|               5|               2|      NAO CHOVEU|
# |09/05|            Arapeí|               5|               2|      NAO CHOVEU|
# +-----+------------------+----------------+----------------+----------------+

# %%
#09/05
sqlTEMP2 = spark.sql("Select date, city, (select count(*) from ForeCast where condition != 'rain' and date ='09/05'), (select count(*) from ForeCast where condition = 'rain' and date ='09/05'), (select 'CHOVEU')  from ForeCast where condition = 'rain' and date='09/05' group by city, date")
sqlTEMP2.show()
# Out:
# +-----+----------------+----------------+----------------+----------------+
# | date|            city|scalarsubquery()|scalarsubquery()|scalarsubquery()|
# +-----+----------------+----------------+----------------+----------------+
# |09/05|       Aparecida|               5|               2|          CHOVEU|
# |09/05|Campos do Jordão|               5|               2|          CHOVEU|
# +-----+----------------+----------------+----------------+----------------+

# %%
dfFinal5 = sqlTEMP1.union(sqlTEMP2)
dfFinal5.show()
# Out:
# +-----+------------------+----------------+----------------+----------------+
# | date|              city|scalarsubquery()|scalarsubquery()|scalarsubquery()|
# +-----+------------------+----------------+----------------+----------------+
# |09/05|Cachoeira Paulista|               5|               2|      NAO CHOVEU|
# |09/05|            Areias|               5|               2|      NAO CHOVEU|
# |09/05|          Caçapava|               5|               2|      NAO CHOVEU|
# |09/05|           Bananal|               5|               2|      NAO CHOVEU|
# |09/05|            Arapeí|               5|               2|      NAO CHOVEU|
# |09/05|         Aparecida|               5|               2|          CHOVEU|
# |09/05|  Campos do Jordão|               5|               2|          CHOVEU|
# +-----+------------------+----------------+----------------+----------------+

# %%
dfFinal1.show()
# Out:
# +-----+------------------+----------------+----------------+----------------+
# | date|              city|scalarsubquery()|scalarsubquery()|scalarsubquery()|
# +-----+------------------+----------------+----------------+----------------+
# |05/05|  Campos do Jordão|               7|               0|      NAO CHOVEU|
# |05/05|          Caçapava|               7|               0|      NAO CHOVEU|
# |05/05|            Arapeí|               7|               0|      NAO CHOVEU|
# |05/05|Cachoeira Paulista|               7|               0|      NAO CHOVEU|
# |05/05|           Bananal|               7|               0|      NAO CHOVEU|
# |05/05|         Aparecida|               7|               0|      NAO CHOVEU|
# |05/05|            Areias|               7|               0|      NAO CHOVEU|
# +-----+------------------+----------------+----------------+----------------+

# %%
dfFinal2.show()
# Out:
# +-----+------------------+----------------+----------------+----------------+
# | date|              city|scalarsubquery()|scalarsubquery()|scalarsubquery()|
# +-----+------------------+----------------+----------------+----------------+
# |06/05|Cachoeira Paulista|               4|               3|      NAO CHOVEU|
# |06/05|         Aparecida|               4|               3|      NAO CHOVEU|
# |06/05|          Caçapava|               4|               3|      NAO CHOVEU|
# |06/05|  Campos do Jordão|               4|               3|      NAO CHOVEU|
# |06/05|            Arapeí|               4|               3|          CHOVEU|
# |06/05|           Bananal|               4|               3|          CHOVEU|
# |06/05|            Areias|               4|               3|          CHOVEU|
# +-----+------------------+----------------+----------------+----------------+

# %%
Tabela2 = dfFinal1.union(dfFinal2)

# %%
Tabela2.show()
# Out:
# +-----+------------------+----------------+----------------+----------------+
# | date|              city|scalarsubquery()|scalarsubquery()|scalarsubquery()|
# +-----+------------------+----------------+----------------+----------------+
# |05/05|  Campos do Jordão|               7|               0|      NAO CHOVEU|
# |05/05|          Caçapava|               7|               0|      NAO CHOVEU|
# |05/05|            Arapeí|               7|               0|      NAO CHOVEU|
# |05/05|Cachoeira Paulista|               7|               0|      NAO CHOVEU|
# |05/05|           Bananal|               7|               0|      NAO CHOVEU|
# |05/05|         Aparecida|               7|               0|      NAO CHOVEU|
# |05/05|            Areias|               7|               0|      NAO CHOVEU|
# |06/05|Cachoeira Paulista|               4|               3|      NAO CHOVEU|
# |06/05|         Aparecida|               4|               3|      NAO CHOVEU|
# |06/05|          Caçapava|               4|               3|      NAO CHOVEU|
# |06/05|  Campos do Jordão|               4|               3|      NAO CHOVEU|
# |06/05|            Arapeí|               4|               3|          CHOVEU|
# |06/05|           Bananal|               4|               3|          CHOVEU|
# |06/05|            Areias|               4|               3|          CHOVEU|
# +-----+------------------+----------------+----------------+----------------+

# %%
Tabela2 = Tabela2.union(dfFinal3)

# %%
Tabela2.show()
# Out:
# +-----+------------------+----------------+----------------+----------------+
# | date|              city|scalarsubquery()|scalarsubquery()|scalarsubquery()|
# +-----+------------------+----------------+----------------+----------------+
# |05/05|  Campos do Jordão|               7|               0|      NAO CHOVEU|
# |05/05|          Caçapava|               7|               0|      NAO CHOVEU|
# |05/05|            Arapeí|               7|               0|      NAO CHOVEU|
# |05/05|Cachoeira Paulista|               7|               0|      NAO CHOVEU|
# |05/05|           Bananal|               7|               0|      NAO CHOVEU|
# |05/05|         Aparecida|               7|               0|      NAO CHOVEU|
# |05/05|            Areias|               7|               0|      NAO CHOVEU|
# |06/05|Cachoeira Paulista|               4|               3|      NAO CHOVEU|
# |06/05|         Aparecida|               4|               3|      NAO CHOVEU|
# |06/05|          Caçapava|               4|               3|      NAO CHOVEU|
# |06/05|  Campos do Jordão|               4|               3|      NAO CHOVEU|
# |06/05|            Arapeí|               4|               3|          CHOVEU|
# |06/05|           Bananal|               4|               3|          CHOVEU|
# |06/05|            Areias|               4|               3|          CHOVEU|
# |07/05|          Caçapava|               2|               5|      NAO CHOVEU|
# |07/05|Cachoeira Paulista|               2|               5|      NAO CHOVEU|
# |07/05|            Arapeí|               2|               5|          CHOVEU|
# |07/05|           Bananal|               2|               5|          CHOVEU|
# |07/05|  Campos do Jordão|               2|               5|          CHOVEU|
# |07/05|            Areias|               2|               5|          CHOVEU|
# +-----+------------------+----------------+----------------+----------------+
# only showing top 20 rows

# %%
dfFinal4.show()
# Out:
# +-----+------------------+----------------+----------------+----------------+
# | date|              city|scalarsubquery()|scalarsubquery()|scalarsubquery()|
# +-----+------------------+----------------+----------------+----------------+
# |08/05|          Caçapava|               2|               5|      NAO CHOVEU|
# |08/05|Cachoeira Paulista|               2|               5|      NAO CHOVEU|
# |08/05|           Bananal|               2|               5|          CHOVEU|
# |08/05|            Arapeí|               2|               5|          CHOVEU|
# |08/05|         Aparecida|               2|               5|          CHOVEU|
# |08/05|            Areias|               2|               5|          CHOVEU|
# |08/05|  Campos do Jordão|               2|               5|          CHOVEU|
# +-----+------------------+----------------+----------------+----------------+

# %%
dfFinal5.show()
# Out:
# +-----+------------------+----------------+----------------+----------------+
# | date|              city|scalarsubquery()|scalarsubquery()|scalarsubquery()|
# +-----+------------------+----------------+----------------+----------------+
# |09/05|Cachoeira Paulista|               5|               2|      NAO CHOVEU|
# |09/05|            Areias|               5|               2|      NAO CHOVEU|
# |09/05|          Caçapava|               5|               2|      NAO CHOVEU|
# |09/05|           Bananal|               5|               2|      NAO CHOVEU|
# |09/05|            Arapeí|               5|               2|      NAO CHOVEU|
# |09/05|         Aparecida|               5|               2|          CHOVEU|
# |09/05|  Campos do Jordão|               5|               2|          CHOVEU|
# +-----+------------------+----------------+----------------+----------------+

# %%
Tabela2 = Tabela2.union(dfFinal4)

# %%
Tabela2 = Tabela2.union(dfFinal5)

# %%
Tabela2
# Out:
# DataFrame[date: string, city: string, scalarsubquery(): bigint, scalarsubquery(): bigint, scalarsubquery(): string]

# %%
Tabela2 = Tabela2.toDF(*("Data", "Cidade", "QtdeLocaisSemChuva", "QtdeLocaisComChuva", "ChoveuNoLocal"))

# %%
Tabela2.show()
# Out:
# +-----+------------------+------------------+------------------+-------------+
# | Data|            Cidade|QtdeLocaisSemChuva|QtdeLocaisComChuva|ChoveuNoLocal|
# +-----+------------------+------------------+------------------+-------------+
# |05/05|  Campos do Jordão|                 7|                 0|   NAO CHOVEU|
# |05/05|          Caçapava|                 7|                 0|   NAO CHOVEU|
# |05/05|            Arapeí|                 7|                 0|   NAO CHOVEU|
# |05/05|Cachoeira Paulista|                 7|                 0|   NAO CHOVEU|
# |05/05|           Bananal|                 7|                 0|   NAO CHOVEU|
# |05/05|         Aparecida|                 7|                 0|   NAO CHOVEU|
# |05/05|            Areias|                 7|                 0|   NAO CHOVEU|
# |06/05|Cachoeira Paulista|                 4|                 3|   NAO CHOVEU|
# |06/05|         Aparecida|                 4|                 3|   NAO CHOVEU|
# |06/05|          Caçapava|                 4|                 3|   NAO CHOVEU|
# |06/05|  Campos do Jordão|                 4|                 3|   NAO CHOVEU|
# |06/05|            Arapeí|                 4|                 3|       CHOVEU|
# |06/05|           Bananal|                 4|                 3|       CHOVEU|
# |06/05|            Areias|                 4|                 3|       CHOVEU|
# |07/05|          Caçapava|                 2|                 5|   NAO CHOVEU|
# |07/05|Cachoeira Paulista|                 2|                 5|   NAO CHOVEU|
# |07/05|            Arapeí|                 2|                 5|       CHOVEU|
# |07/05|           Bananal|                 2|                 5|       CHOVEU|
# |07/05|  Campos do Jordão|                 2|                 5|       CHOVEU|
# |07/05|            Areias|                 2|                 5|       CHOVEU|
# +-----+------------------+------------------+------------------+-------------+
# only showing top 20 rows

# %%
Tabela2 = Tabela2.select("*").toPandas()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [433], in <cell line: 1>()
# ----> 1 Tabela2 = Tabela2.select("*").toPandas()
#
# File ~\anaconda3\envs\inteligencia_artificial\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'select'

# %%
Tabela2.to_csv("Tabela2A.csv")

# %%
#Transformar tabela2 em spark de novo

# %%
Tabela2 = dfFinal1.union(dfFinal2)
Tabela2.show()
# Out:
# +-----+------------------+----------------+----------------+----------------+
# | date|              city|scalarsubquery()|scalarsubquery()|scalarsubquery()|
# +-----+------------------+----------------+----------------+----------------+
# |05/05|  Campos do Jordão|               7|               0|      NAO CHOVEU|
# |05/05|          Caçapava|               7|               0|      NAO CHOVEU|
# |05/05|            Arapeí|               7|               0|      NAO CHOVEU|
# |05/05|Cachoeira Paulista|               7|               0|      NAO CHOVEU|
# |05/05|           Bananal|               7|               0|      NAO CHOVEU|
# |05/05|         Aparecida|               7|               0|      NAO CHOVEU|
# |05/05|            Areias|               7|               0|      NAO CHOVEU|
# |06/05|Cachoeira Paulista|               4|               3|      NAO CHOVEU|
# |06/05|         Aparecida|               4|               3|      NAO CHOVEU|
# |06/05|          Caçapava|               4|               3|      NAO CHOVEU|
# |06/05|  Campos do Jordão|               4|               3|      NAO CHOVEU|
# |06/05|            Arapeí|               4|               3|          CHOVEU|
# |06/05|           Bananal|               4|               3|          CHOVEU|
# |06/05|            Areias|               4|               3|          CHOVEU|
# +-----+------------------+----------------+----------------+----------------+

# %%
Tabela2 = Tabela2.union(dfFinal3)

# %%
Tabela2 = Tabela2.union(dfFinal4)

# %%
Tabela2 = Tabela2.union(dfFinal5)

# %%
Tabela2 = Tabela2.toDF(*("Data", "Cidade", "QtdeLocaisSemChuva", "QtdeLocaisComChuva", "ChoveuNoLocal"))

# %%
Tabela2.createOrReplaceTempView("ConsultaFinal")

# %%
sqlTEMP1 = spark.sql("select Cidade, count(ChoveuNoLocal) from ConsultaFinal where ChoveuNoLocal != 'CHOVEU' group by Cidade ")

# %%
sqlTEMP1.show() #mostra dias sem chuva
# Out:
# +------------------+--------------------+
# |            Cidade|count(ChoveuNoLocal)|
# +------------------+--------------------+
# |         Aparecida|                   2|
# |            Arapeí|                   2|
# |Cachoeira Paulista|                   5|
# |  Campos do Jordão|                   2|
# |           Bananal|                   2|
# |            Areias|                   2|
# |          Caçapava|                   5|
# +------------------+--------------------+

# %%
sqlTEMP2 = spark.sql("select Cidade, count(ChoveuNoLocal) from ConsultaFinal where ChoveuNoLocal = 'CHOVEU' group by Cidade ")
sqlTEMP2.show() #registros de chuva
# Out:
# +----------------+--------------------+
# |          Cidade|count(ChoveuNoLocal)|
# +----------------+--------------------+
# |          Arapeí|                   3|
# |         Bananal|                   3|
# |          Areias|                   3|
# |       Aparecida|                   3|
# |Campos do Jordão|                   3|
# +----------------+--------------------+

# %%
#### relatório final
##final = spark.sql("select TEMP1.Cidade, TEMP1.count(ChoveunoLocal), TEMP2.count(ChoveuNoLocal) from TEMP1 left join TEMP2 on TEMP1.Cidade = TEMP2.Cidade")

##fazendo o equivalente ao left join

final = sqlTEMP1.join(sqlTEMP2, on=['Cidade'], how='left')

# %%
final.show()
# Out:
# +------------------+--------------------+--------------------+
# |            Cidade|count(ChoveuNoLocal)|count(ChoveuNoLocal)|
# +------------------+--------------------+--------------------+
# |         Aparecida|                   2|                   3|
# |            Arapeí|                   2|                   3|
# |Cachoeira Paulista|                   5|                null|
# |  Campos do Jordão|                   2|                   3|
# |           Bananal|                   2|                   3|
# |            Areias|                   2|                   3|
# |          Caçapava|                   5|                null|
# +------------------+--------------------+--------------------+

# %%
final = final.toDF(*("Cidade", "Dias sem chuva", "Dias com chuva")) 
final.show()
# Out:
# +------------------+--------------+--------------+
# |            Cidade|Dias sem chuva|Dias com chuva|
# +------------------+--------------+--------------+
# |         Aparecida|             2|             3|
# |            Arapeí|             2|             3|
# |Cachoeira Paulista|             5|          null|
# |  Campos do Jordão|             2|             3|
# |           Bananal|             2|             3|
# |            Areias|             2|             3|
# |          Caçapava|             5|          null|
# +------------------+--------------+--------------+

# %%
final = final.select("*").toPandas()
final.to_csv("Tabela2B.csv")
